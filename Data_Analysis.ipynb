# %%
import pandas as pd
import sqlalchemy
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import TextBox
import scipy.stats as stats
from scipy.stats import ttest_ind
import statsmodels.api as sm
from statsmodels.formula.api import ols
from pathlib import Path
import plotly.graph_objects as go
import plotly.express as px
from ipywidgets import widgets, interactive
import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output

# %%
#Read in the historic data and store in a DataFrame
path = "data/HistoricalPollution.csv"
historic_df = pd.read_csv(path)

#Take a look at the data
historic_df
# Out:
#      Primary Key   CBSA       City State Pollutant       Trend Statistic  \
# 0              1  10420      Akron    OH        O3               4th Max
# 1              2  10420      Akron    OH     PM2.5  Weighted Annual Mean
# 2              3  10420      Akron    OH     PM2.5       98th Percentile
# 3              4  10420      Akron    OH       SO2       99th Percentile
# 4              5  10500     Albany    GA     PM2.5  Weighted Annual Mean
# ..           ...    ...        ...   ...       ...                   ...
# 708          709  49700  Yuba City    CA       NO2           Annual Mean
# 709          710  49700  Yuba City    CA       NO2       98th Percentile
# 710          711  49700  Yuba City    CA        O3               4th Max
# 711          712  49700  Yuba City    CA     PM2.5  Weighted Annual Mean
# 712          713  49700  Yuba City    CA     PM2.5       98th Percentile
#
#      Number of Sites     1990     1991     1992  ...    2013    2014    2015  \
# 0                  2    0.090    0.101    0.087  ...   0.059   0.060   0.065
# 1                  3      NaN      NaN      NaN  ...   9.700   9.900  10.400
# 2                  3      NaN      NaN      NaN  ...  24.000  22.000  23.000
# 3                  1  161.000  183.000  181.000  ...  23.000  21.000  14.000
# 4                  1      NaN      NaN      NaN  ...  10.000  10.300   9.000
# ..               ...      ...      ...      ...  ...     ...     ...     ...
# 708                1   17.000   17.000   17.000  ...  10.000   8.000   7.000
# 709                1   70.000   70.000   70.000  ...  52.000  44.000  39.000
# 710                1    0.076    0.080    0.090  ...   0.060   0.069   0.064
# 711                1      NaN      NaN      NaN  ...   8.200   9.400   9.600
# 712                1      NaN      NaN      NaN  ...  25.000  25.000  31.000
#
#        2016    2017    2018    2019    2020    2021    2022
# 0     0.060   0.066   0.068   0.062   0.063   0.067   0.070
# 1     8.200   7.900   7.900   8.200   7.900   8.000   7.100
# 2    17.000  18.000  18.000  21.000  21.000  20.000  17.000
# 3     8.000   3.000   6.000   3.000   4.000   5.000   6.000
# 4     8.700   9.400   8.400   9.300   9.100  10.100   8.300
# ..      ...     ...     ...     ...     ...     ...     ...
# 708   7.000   7.000   7.000   6.000   6.000   5.000   7.000
# 709  40.000  42.000  41.000  40.000  38.000  34.000  37.000
# 710   0.063   0.067   0.065   0.061   0.066   0.072   0.058
# 711   8.100   9.300  10.300   8.400  16.400  14.500  10.700
# 712  22.000  32.000  37.000  27.000  91.000  45.000  28.000
#
# [713 rows x 40 columns]

# %%
#Dropping the years 1990 - 1999 because most of the pollutant data is missing from these years. We will get more accurate data to compare looking at years 2000-2022

drop_col = ['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999']
mean_2000 = historic_df.drop(columns=drop_col)
mean_2000
# Out:
#      Primary Key   CBSA       City State Pollutant       Trend Statistic  \
# 0              1  10420      Akron    OH        O3               4th Max
# 1              2  10420      Akron    OH     PM2.5  Weighted Annual Mean
# 2              3  10420      Akron    OH     PM2.5       98th Percentile
# 3              4  10420      Akron    OH       SO2       99th Percentile
# 4              5  10500     Albany    GA     PM2.5  Weighted Annual Mean
# ..           ...    ...        ...   ...       ...                   ...
# 708          709  49700  Yuba City    CA       NO2           Annual Mean
# 709          710  49700  Yuba City    CA       NO2       98th Percentile
# 710          711  49700  Yuba City    CA        O3               4th Max
# 711          712  49700  Yuba City    CA     PM2.5  Weighted Annual Mean
# 712          713  49700  Yuba City    CA     PM2.5       98th Percentile
#
#      Number of Sites     2000     2001    2002  ...    2013    2014    2015  \
# 0                  2    0.085    0.096    0.10  ...   0.059   0.060   0.065
# 1                  3   16.200   16.200   16.00  ...   9.700   9.900  10.400
# 2                  3   37.000   44.000   40.00  ...  24.000  22.000  23.000
# 3                  1  163.000  132.000  145.00  ...  23.000  21.000  14.000
# 4                  1   16.600   14.600   13.80  ...  10.000  10.300   9.000
# ..               ...      ...      ...     ...  ...     ...     ...     ...
# 708                1   13.000   14.000   15.00  ...  10.000   8.000   7.000
# 709                1   67.000   64.000   62.00  ...  52.000  44.000  39.000
# 710                1    0.079    0.081    0.08  ...   0.060   0.069   0.064
# 711                1   10.600   11.900   13.10  ...   8.200   9.400   9.600
# 712                1   38.000   54.000   34.00  ...  25.000  25.000  31.000
#
#        2016    2017    2018    2019    2020    2021    2022
# 0     0.060   0.066   0.068   0.062   0.063   0.067   0.070
# 1     8.200   7.900   7.900   8.200   7.900   8.000   7.100
# 2    17.000  18.000  18.000  21.000  21.000  20.000  17.000
# 3     8.000   3.000   6.000   3.000   4.000   5.000   6.000
# 4     8.700   9.400   8.400   9.300   9.100  10.100   8.300
# ..      ...     ...     ...     ...     ...     ...     ...
# 708   7.000   7.000   7.000   6.000   6.000   5.000   7.000
# 709  40.000  42.000  41.000  40.000  38.000  34.000  37.000
# 710   0.063   0.067   0.065   0.061   0.066   0.072   0.058
# 711   8.100   9.300  10.300   8.400  16.400  14.500  10.700
# 712  22.000  32.000  37.000  27.000  91.000  45.000  28.000
#
# [713 rows x 30 columns]

# %%
#store all the years as a list to call easier
years = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']

# %%
#Create a dataframe containing state, city, and year total pollutiion

state_df = (mean_2000.groupby(['State', 'City'], sort=True, as_index=False)[years].sum())
state_df
# Out:
#     State          City     2000     2001     2002     2003     2004     2005  \
# 0      AK     Anchorage   31.200   36.900   35.500   35.300   43.300   33.500
# 1      AK        Juneau   30.600   31.600   26.200   29.400   32.600   43.100
# 2      AL    Birmingham  320.791  189.683  148.185  157.877  162.974  180.584
# 3      AL        Daphne   50.500   32.600   33.400   41.200   39.400   37.700
# 4      AL       Decatur   44.100   44.100   44.100   43.700   41.200   49.700
# ..    ...           ...      ...      ...      ...      ...      ...      ...
# 240    WY      Gillette   73.000   65.000   69.000   66.000   63.000   56.000
# 241    WY       Laramie    0.043    0.051    0.044    0.049    0.048    0.038
# 242    WY      Riverton   91.600   85.600   99.600   84.100   99.600   88.700
# 243    WY  Rock Springs   32.200   32.500   42.000   32.200   32.000   31.200
# 244    WY      Sheridan   47.100   51.000   38.100   36.100   49.000   42.500
#
#         2006     2007  ...    2013    2014     2015    2016    2017    2018  \
# 0     44.200   25.800  ...  30.700  38.500   37.300  32.100  37.100  25.700
# 1     41.500   46.600  ...  28.900  35.700   27.600  30.000  27.600  28.900
# 2    168.486  164.292  ...  87.065  84.364  113.268  73.670  70.562  69.265
# 3     37.200   32.400  ...  25.400  25.900   26.600  21.200  26.400  24.100
# 4     42.200   54.400  ...  24.600  30.300   25.800  20.400  23.700  23.400
# ..       ...      ...  ...     ...     ...      ...     ...     ...     ...
# 240   88.000   94.000  ...  64.000  47.000   78.000  50.000  95.000  39.000
# 241    0.047    0.042  ...   0.069   0.065    0.064   0.064   0.066   0.070
# 242   77.700   72.500  ...  75.800  83.700   61.200  58.800  73.400  71.300
# 243   36.500   40.200  ...  37.000  29.300   35.300  30.700  45.800  45.000
# 244   33.700   36.400  ...  23.700  25.500   32.500  29.900  32.700  28.200
#
#        2019     2020    2021    2022
# 0    44.800   31.300  27.400  30.100
# 1    31.800   21.800  21.700  28.300
# 2    66.471   61.961  68.861  63.064
# 3    22.500   24.900  22.300  22.300
# 4    21.600   23.100  33.000  29.500
# ..      ...      ...     ...     ...
# 240  39.000   61.000  84.000  72.000
# 241   0.065    0.066   0.072   0.067
# 242  67.000  105.300  98.500  81.800
# 243  35.000   69.800  47.300  46.200
# 244  24.000   40.400  35.500  35.500
#
# [245 rows x 25 columns]

# %%
#Making a new dataframe from the above containing the averages for a future line graph
state_avg = state_df.groupby('State').mean().reset_index()
state_avg.head()
# Out:
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_5986/3824548273.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   state_avg = state_df.groupby('State').mean().reset_index()
#   State        2000        2001        2002       2003       2004       2005  \
# 0    AK   30.900000   34.250000   30.850000  32.350000  37.950000  38.300000
# 1    AL   83.673250   56.981000   51.205875  52.017125  53.290500  58.441375
# 2    AR   24.809500   23.400000   22.658000  19.503500  20.147500  26.905500
# 3    AZ   74.719600   68.316200   63.182000  75.280200  50.197000  59.020600
# 4    CA  107.987429  114.352964  106.465679  91.628786  86.646643  88.873179
#
#         2006       2007       2008  ...       2013       2014       2015  \
# 0  42.850000  36.200000  35.400000  ...  29.800000  37.100000  32.450000
# 1  52.945000  55.918125  47.116250  ...  30.514000  32.127250  36.114625
# 2  19.158500  21.443500  18.852500  ...  15.767000  16.162500  14.911500
# 3  71.339000  61.176000  61.557200  ...  70.117200  71.514800  47.254400
# 4  90.562429  90.169214  94.056393  ...  79.676286  76.061071  71.457071
#
#         2016       2017        2018       2019        2020       2021  \
# 0  31.050000  32.350000   27.300000  38.300000   26.550000  24.550000
# 1  27.252500  27.500375   27.114875  25.964250   27.372125  28.748875
# 2  14.259500  13.659000   15.214000  14.308000   13.157000  15.213500
# 3  57.812600  62.915200   78.015400  46.892600   59.695600  71.015400
# 4  65.588286  84.593143  112.890643  65.724429  108.160893  83.341393
#
#         2022
# 0  29.200000
# 1  27.363625
# 2  14.511500
# 3  57.314000
# 4  71.395857
#
# [5 rows x 24 columns]

# %%
state_avg.set_index('State', inplace=True)

# %%
#Transpose the data to build a line graph
state_avg_pose = state_avg.transpose()
state_avg_pose.head()
# Out:
# State     AK         AL       AR       AZ          CA         CO         CT  \
# 2000   30.90  83.673250  24.8095  74.7196  107.987429  73.302000  72.685667
# 2001   34.25  56.981000  23.4000  68.3162  114.352964  76.385167  76.666000
# 2002   30.85  51.205875  22.6580  63.1820  106.465679  72.355000  72.639667
# 2003   32.35  52.017125  19.5035  75.2802   91.628786  67.056833  74.493000
# 2004   37.95  53.290500  20.1475  50.1970   86.646643  68.984167  64.746000
#
# State    DE         FL         GA  ...         SC       TN       TX  \
# 2000   47.2  96.115667  53.947625  ...  51.851333  4.84275  72.9597
# 2001   47.0  89.755167  49.681875  ...  50.180333  4.58625  67.9428
# 2002   60.1  80.041000  46.156375  ...  43.218000  4.09500  67.7384
# 2003   43.7  73.236167  45.568000  ...  42.876667  2.08200  67.0863
# 2004   43.6  77.194000  49.467625  ...  47.776667  4.07475  64.7533
#
# State         UT        VA         VT        WA         WI        WV       WY
# 2000   63.231667  100.2305  37.580000  24.64400  45.371857  127.1944  48.7886
# 2001   80.727000  104.7390  34.419667  23.34300  43.190286  129.7734  46.8302
# 2002   73.963000  106.6450  39.756667  22.71950  38.604857  136.3164  49.7488
# 2003   65.259667  104.6285  38.515667  21.55000  38.360714  110.2342  43.6898
# 2004   86.322333   98.9730  37.381667  24.34825  38.281714  119.4276  48.7296
#
# [5 rows x 47 columns]

# %%
state_avg_pose.reset_index(inplace=True)

# %%
state_avg_pose.rename(columns={'index':'Year'})
# Out:
# State  Year     AK         AL       AR       AZ          CA         CO  \
# 0      2000  30.90  83.673250  24.8095  74.7196  107.987429  73.302000
# 1      2001  34.25  56.981000  23.4000  68.3162  114.352964  76.385167
# 2      2002  30.85  51.205875  22.6580  63.1820  106.465679  72.355000
# 3      2003  32.35  52.017125  19.5035  75.2802   91.628786  67.056833
# 4      2004  37.95  53.290500  20.1475  50.1970   86.646643  68.984167
# 5      2005  38.30  58.441375  26.9055  59.0206   88.873179  61.287500
# 6      2006  42.85  52.945000  19.1585  71.3390   90.562429  57.705833
# 7      2007  36.20  55.918125  21.4435  61.1760   90.169214  67.487167
# 8      2008  35.40  47.116250  18.8525  61.5572   94.056393  64.153000
# 9      2009  38.20  37.085375  16.9465  59.8730   77.480500  55.500500
# 10     2010  38.70  42.627500  17.2005  48.6566   67.668714  58.835833
# 11     2011  32.75  41.194125  18.5710  77.6396   74.592821  56.204500
# 12     2012  35.95  34.207750  17.2215  62.2390   70.450214  64.972667
# 13     2013  29.80  30.514000  15.7670  70.1172   79.676286  60.704333
# 14     2014  37.10  32.127250  16.1625  71.5148   76.061071  61.135167
# 15     2015  32.45  36.114625  14.9115  47.2544   71.457071  56.502667
# 16     2016  31.05  27.252500  14.2595  57.8126   65.588286  56.634667
# 17     2017  32.35  27.500375  13.6590  62.9152   84.593143  53.685167
# 18     2018  27.30  27.114875  15.2140  78.0154  112.890643  54.702833
# 19     2019  38.30  25.964250  14.3080  46.8926   65.724429  57.633000
# 20     2020  26.55  27.372125  13.1570  59.6956  108.160893  73.236833
# 21     2021  24.55  28.748875  15.2135  71.0154   83.341393  62.355500
# 22     2022  29.20  27.363625  14.5115  57.3140   71.395857  45.719167
#
# State         CT    DE         FL  ...         SC       TN       TX  \
# 0      72.685667  47.2  96.115667  ...  51.851333  4.84275  72.9597
# 1      76.666000  47.0  89.755167  ...  50.180333  4.58625  67.9428
# 2      72.639667  60.1  80.041000  ...  43.218000  4.09500  67.7384
# 3      74.493000  43.7  73.236167  ...  42.876667  2.08200  67.0863
# 4      64.746000  43.6  77.194000  ...  47.776667  4.07475  64.7533
# 5      73.593333  48.2  75.828333  ...  51.180333  4.58125  65.8329
# 6      66.092000  42.9  76.704917  ...  41.846667  4.33100  72.7729
# 7      62.524667  43.1  74.102167  ...  48.076333  4.58475  64.5671
# 8      57.114667  39.3  64.249500  ...  36.710667  3.82675  59.5450
# 9      54.671667  30.5  55.052917  ...  37.031000  3.06725  53.1353
# 10     51.679667  30.3  55.655667  ...  40.904333  3.32650  53.7873
# 11     56.616667  32.6  49.189750  ...  43.406667  3.07425  52.4503
# 12     43.952333  29.2  46.046500  ...  33.563000  3.07625  51.8771
# 13     48.849333  32.1  43.594167  ...  30.893333  2.81400  46.0235
# 14     48.674000  32.2  48.002667  ...  30.027667  2.56600  46.0894
# 15     49.513000  30.7  39.475333  ...  30.826333  2.31700  43.9455
# 16     45.412333  26.6  37.042583  ...  40.831000  2.31825  39.5491
# 17     42.378333  24.7  44.570000  ...  27.895333  2.06425  42.5210
# 18     44.010000  24.5  38.403083  ...  27.126667  2.06675  46.4238
# 19     40.479000  26.6  42.942750  ...  34.892000  1.81350  39.6112
# 20     44.206000  20.4  42.849250  ...  32.690000  1.80800  43.3887
# 21     44.377000  24.4  43.307167  ...  32.427667  1.81325  44.8309
# 22     41.775333  24.4  47.242500  ...  34.494333  1.56275  44.9805
#
# State         UT        VA         VT        WA         WI        WV       WY
# 0      63.231667  100.2305  37.580000  24.64400  45.371857  127.1944  48.7886
# 1      80.727000  104.7390  34.419667  23.34300  43.190286  129.7734  46.8302
# 2      73.963000  106.6450  39.756667  22.71950  38.604857  136.3164  49.7488
# 3      65.259667  104.6285  38.515667  21.55000  38.360714  110.2342  43.6898
# 4      86.322333   98.9730  37.381667  24.34825  38.281714  119.4276  48.7296
# 5      58.364000  106.8290  37.580667  23.49375  48.432714  113.2126  43.6876
# 6      57.760667  100.8785  31.611000  22.12350  43.182286  105.0314  47.1894
# 7      86.294000  103.2290  32.584667  21.41850  45.044143  115.8332  48.6284
# 8      87.826000   73.8270  27.847000  20.89025  42.765571   98.1894  42.6088
# 9      91.323667   65.0140  25.742667  22.64175  42.194571   95.5846  45.8098
# 10     72.891333   66.9260  23.943667  17.96475  40.766571   59.4286  42.5696
# 11     53.356000   61.0725  25.705667  19.78825  35.768000   52.2690  42.3530
# 12     43.955667   48.7230  19.211333  19.39225  34.644571   37.8300  47.3342
# 13     97.720667   51.5100  15.841333  21.58825  32.395143   36.4662  40.1138
# 14     49.091333   52.1115  19.973333  17.53975  34.868143   36.6868  37.1130
# 15     46.124333   47.4120  16.909667  19.16750  31.466143   38.6076  41.4128
# 16     49.025333   46.4645  11.709000  16.23875  21.154571   29.3072  33.8928
# 17     54.059333   39.6605  11.275000  26.17350  19.451571   29.8450  49.3932
# 18     55.360000   38.9120  12.509000  25.92525  22.039143   29.3654  36.7140
# 19     37.091000   37.4600  12.870000  17.71325  23.149429   29.4452  33.0130
# 20     51.593333   30.5540  12.836333  43.14025  20.453286   27.4630  55.3132
# 21     61.327333   34.3100  12.174667  26.04550  26.052429   30.9244  53.0744
# 22     48.758333   32.3090  11.371333  19.66850  21.623143   27.5246  47.1134
#
# [23 rows x 48 columns]

# %%
#Creating a dash app to display a line chart that shows overall pollution by year with a dropdown for each state

# Create a Dash app
appState = dash.Dash(__name__)


dropdown_options = [{'label': col, 'value': col} for col in state_avg_pose.columns[1:]]

# Define app layout
appState.layout = html.Div([
    dcc.Dropdown(
        id='dropdown',
        options=[{'label': state, 'value': state} for state in state_avg_pose.columns[1:]],
        value='AK'
    ),
    dcc.Graph(id='line-plot1')
])

# Define callback to update the line plot
@appState.callback(
    Output('line-plot1', 'figure'),
    [Input('dropdown', 'value')]
)
def update_line_plot(selected_column):
    fig = px.line(state_avg_pose, x='index', y=selected_column)

    title = f'{selected_column} pollution'

    return fig

# Run the app
if __name__ == '__main__':
    appState.run_server(debug=True, port=8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Using the above table, perform a t-test for each state checking for significant difference at the 0.05 significance level between overall pollution in 1990 and 2022.

for state in state_df['State'].unique():
    data_2000 = state_df.loc[state_df['State'] == state, '2000']
    data_2022 = state_df.loc[state_df['State'] == state, '2022']

    t_statistic, p_value = ttest_ind(data_2000, data_2022)

    print(f'State: {state}')
    print(f't_statistic: {t_statistic}')
    print(f'p_value: {p_value}')
    if p_value < 0.05:
        print('There is a significant difference between pollution in 2000 and 2022')

        if p_value > 0:
            print('There is a significant decrease in overall pollution')

            if t_statistic > 0:
                print('There was a significant decrease in pollution between 2000 and 2022')
            else:
                print('There was a significant increase in pollution between 2000 and 2022')

        else:
            print('There is a significant increase in ovall pollution')

    else:
        print('No significant difference between pollution in 2000 and 2022')

    print('-------------------------------')
    print('-------------------------------')
# Out:
# State: AK
# t_statistic: 1.7919573407620772
# p_value: 0.21501293588266346
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: AL
# t_statistic: 1.509119356832565
# p_value: 0.15350272780958907
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: AR
# t_statistic: 0.35898337317828977
# p_value: 0.7539633195973889
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: AZ
# t_statistic: 0.37094151853907686
# p_value: 0.7203114747322884
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: CA
# t_statistic: 1.6670329313806622
# p_value: 0.10129822141399748
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: CO
# t_statistic: 0.9068059874114897
# p_value: 0.38583897457444283
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: CT
# t_statistic: 1.1024462679867428
# p_value: 0.3321372814411028
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: DE
# t_statistic: nan
# p_value: nan
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: FL
# t_statistic: 1.8634566238385488
# p_value: 0.07580167416626808
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: GA
# t_statistic: 2.0405161039209263
# p_value: 0.06062564299210071
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: HI
# t_statistic: 0.3867218468681709
# p_value: 0.7362305165745375
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: IA
# t_statistic: 0.6465995476798266
# p_value: 0.5418197360593943
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: IL
# t_statistic: 0.6591564859626166
# p_value: 0.5342603601718912
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: IN
# t_statistic: 1.8518774507772702
# p_value: 0.08051825256107223
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: KS
# t_statistic: nan
# p_value: nan
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: KY
# t_statistic: 1.2585077560009938
# p_value: 0.2367962410854988
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: LA
# t_statistic: 1.2037737300113978
# p_value: 0.25188607494431214
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: MA
# t_statistic: 0.5842705320019365
# p_value: 0.6181623331201782
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: MD
# t_statistic: nan
# p_value: nan
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: ME
# t_statistic: 2.7854300726557777
# p_value: 0.049542753364461636
# There is a significant difference between pollution in 2000 and 2022
# There is a significant decrease in overall pollution
# There was a significant decrease in pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MI
# t_statistic: 0.7203982739740523
# p_value: 0.4816728516436035
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: MN
# t_statistic: 3.032739979663868
# p_value: 0.09369492398760829
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: MO
# t_statistic: 0.5708753705723302
# p_value: 0.6256775199318834
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: MT
# t_statistic: 1.03187147995975
# p_value: 0.36043483683243915
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NC
# t_statistic: 1.4805735647291767
# p_value: 0.15430242918558273
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: ND
# t_statistic: 0.5293751799782256
# p_value: 0.6494310255492112
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NE
# t_statistic: nan
# p_value: nan
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NH
# t_statistic: 0.7790398451808136
# p_value: 0.46556251544613825
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NJ
# t_statistic: 1.1713252398688192
# p_value: 0.30648054846483963
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NM
# t_statistic: -0.35001116581060143
# p_value: 0.7597534000968444
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NV
# t_statistic: -0.04240574964002057
# p_value: 0.9700280780750383
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NY
# t_statistic: 1.210142974676009
# p_value: 0.2462605610101202
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: OH
# t_statistic: 2.2301524662276977
# p_value: 0.03534885283055519
# There is a significant difference between pollution in 2000 and 2022
# There is a significant decrease in overall pollution
# There was a significant decrease in pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OK
# t_statistic: 1.1471937071876557
# p_value: 0.31525381630047306
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: OR
# t_statistic: -0.7431949152475195
# p_value: 0.4854348452899655
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: PA
# t_statistic: 2.0421613379674888
# p_value: 0.051400630452641954
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: PR
# t_statistic: nan
# p_value: nan
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: SC
# t_statistic: 0.4413991078927323
# p_value: 0.6817348941536943
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: TN
# t_statistic: 0.6588118633389106
# p_value: 0.5344669237041608
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: TX
# t_statistic: 0.8191529345696595
# p_value: 0.423412828158356
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: UT
# t_statistic: 0.2910394400444567
# p_value: 0.7854885788013977
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: VA
# t_statistic: 2.967599620066812
# p_value: 0.09726597051933387
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: VT
# t_statistic: 0.6689423986298781
# p_value: 0.540159297482557
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: WA
# t_statistic: 0.27388586312299773
# p_value: 0.7933569759041226
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: WI
# t_statistic: 1.3634477714718864
# p_value: 0.19777414411776875
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: WV
# t_statistic: 2.125053009601314
# p_value: 0.06630163791915927
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: WY
# t_statistic: 0.07791734695181364
# p_value: 0.9398073879076851
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_5986/2884399982.py:7: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_statistic, p_value = ttest_ind(data_1990, data_2022)
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero

# %% [markdown]
# For the following we will look at each pollutant seperately.

# %%
#Create a dataframe containing only the pollutant O3
O3 = ['O3']
O3_df = mean_2000[mean_2000['Pollutant'].isin(O3) == True]
state_O3 = (O3_df.groupby(['State', 'City'], sort=True, as_index=False)[years].sum())
state_O3
# Out:
#     State         City   2000   2001   2002   2003   2004   2005   2006  \
# 0      AL   Birmingham  0.091  0.083  0.085  0.077  0.074  0.084  0.086
# 1      AL   Fort Payne  0.034  0.032  0.029  0.030  0.027  0.030  0.038
# 2      AL   Huntsville  0.088  0.080  0.078  0.079  0.077  0.075  0.079
# 3      AL       Mobile  0.089  0.076  0.075  0.080  0.074  0.073  0.085
# 4      AL   Montgomery  0.084  0.077  0.080  0.071  0.072  0.069  0.072
# ..    ...          ...    ...    ...    ...    ...    ...    ...    ...
# 170    WI       Wausau  0.073  0.072  0.073  0.074  0.065  0.075  0.066
# 171    WI   Whitewater  0.076  0.088  0.084  0.081  0.069  0.083  0.072
# 172    WV   Charleston  0.085  0.083  0.087  0.088  0.069  0.079  0.077
# 173    WV  Parkersburg  0.087  0.084  0.095  0.083  0.069  0.084  0.080
# 174    WY      Laramie  0.043  0.051  0.044  0.049  0.048  0.038  0.047
#
#       2007  ...   2013   2014   2015   2016   2017   2018   2019   2020  \
# 0    0.092  ...  0.065  0.064  0.068  0.070  0.062  0.065  0.071  0.061
# 1    0.020  ...  0.062  0.062  0.065  0.064  0.058  0.064  0.062  0.057
# 2    0.082  ...  0.064  0.064  0.063  0.066  0.063  0.065  0.063  0.057
# 3    0.077  ...  0.060  0.068  0.060  0.062  0.065  0.065  0.059  0.054
# 4    0.074  ...  0.061  0.060  0.061  0.058  0.055  0.060  0.059  0.048
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 170  0.072  ...  0.063  0.064  0.063  0.068  0.060  0.065  0.059  0.055
# 171  0.075  ...  0.067  0.073  0.067  0.072  0.065  0.070  0.062  0.074
# 172  0.082  ...  0.067  0.067  0.067  0.069  0.067  0.066  0.065  0.057
# 173  0.084  ...  0.064  0.067  0.071  0.067  0.058  0.061  0.061  0.058
# 174  0.042  ...  0.069  0.065  0.064  0.064  0.066  0.070  0.065  0.066
#
#       2021   2022
# 0    0.061  0.064
# 1    0.058  0.061
# 2    0.061  0.065
# 3    0.057  0.061
# 4    0.054  0.058
# ..     ...    ...
# 170  0.060  0.057
# 171  0.069  0.070
# 172  0.065  0.061
# 173  0.057  0.062
# 174  0.072  0.067
#
# [175 rows x 25 columns]

# %%
O3_avg = state_O3.groupby('State').mean().reset_index()
O3_avg.head()
# Out:
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_5986/1882764809.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   State      2000      2001      2002      2003      2004      2005      2006  \
# 0    AL  0.077200  0.069600  0.069400  0.067400  0.064800  0.066200  0.072000
# 1    AR  0.059500  0.050000  0.058000  0.053500  0.047500  0.055500  0.058500
# 2    AZ  0.074500  0.070250  0.077500  0.075250  0.071250  0.075750  0.073750
# 3    CA  0.078476  0.080143  0.082810  0.081238  0.076476  0.073762  0.078476
# 4    CO  0.070667  0.070333  0.076667  0.080333  0.068333  0.075000  0.078333
#
#        2007      2008  ...      2013      2014      2015      2016      2017  \
# 0  0.069000  0.066000  ...  0.062400  0.063600  0.063400  0.064000  0.060600
# 1  0.043500  0.052500  ...  0.067000  0.062500  0.061500  0.059500  0.059000
# 2  0.070000  0.071500  ...  0.071500  0.068500  0.068000  0.065750  0.069000
# 3  0.073238  0.079952  ...  0.068381  0.071905  0.071333  0.070095  0.071810
# 4  0.074333  0.072667  ...  0.075333  0.070333  0.072000  0.069333  0.070333
#
#        2018      2019      2020      2021      2022
# 0  0.063800  0.062800  0.055400  0.058200  0.061800
# 1  0.064000  0.058000  0.057000  0.063500  0.061500
# 2  0.069250  0.065750  0.069500  0.069250  0.067500
# 3  0.068476  0.065905  0.071667  0.069476  0.065905
# 4  0.072333  0.066000  0.073667  0.077667  0.071667
#
# [5 rows x 24 columns]

# %%
state_O3.set_index('City', inplace=True)

# %%
state_O3.head()
# Out:
#            State   2000   2001   2002   2003   2004   2005   2006   2007  \
# City
# Birmingham    AL  0.091  0.083  0.085  0.077  0.074  0.084  0.086  0.092
# Fort Payne    AL  0.034  0.032  0.029  0.030  0.027  0.030  0.038  0.020
# Huntsville    AL  0.088  0.080  0.078  0.079  0.077  0.075  0.079  0.082
# Mobile        AL  0.089  0.076  0.075  0.080  0.074  0.073  0.085  0.077
# Montgomery    AL  0.084  0.077  0.080  0.071  0.072  0.069  0.072  0.074
#
#              2008  ...   2013   2014   2015   2016   2017   2018   2019  \
# City               ...
# Birmingham  0.077  ...  0.065  0.064  0.068  0.070  0.062  0.065  0.071
# Fort Payne  0.036  ...  0.062  0.062  0.065  0.064  0.058  0.064  0.062
# Huntsville  0.073  ...  0.064  0.064  0.063  0.066  0.063  0.065  0.063
# Mobile      0.076  ...  0.060  0.068  0.060  0.062  0.065  0.065  0.059
# Montgomery  0.068  ...  0.061  0.060  0.061  0.058  0.055  0.060  0.059
#
#              2020   2021   2022
# City
# Birmingham  0.061  0.061  0.064
# Fort Payne  0.057  0.058  0.061
# Huntsville  0.057  0.061  0.065
# Mobile      0.054  0.057  0.061
# Montgomery  0.048  0.054  0.058
#
# [5 rows x 24 columns]

# %%
city_O3 = state_O3.transpose()

# %%
city_O3.reset_index(inplace=True)

# %%
city_O3 = city_O3.drop(index=0)

# %%
city_O3.head()
# Out:
# City index Birmingham Fort Payne Huntsville Mobile Montgomery Arkadelphia  \
# 1     2000      0.091      0.034      0.088  0.089      0.084       0.029
# 2     2001      0.083      0.032       0.08  0.076      0.077       0.021
# 3     2002      0.085      0.029      0.078  0.075       0.08       0.031
# 4     2003      0.077       0.03      0.079   0.08      0.071       0.032
# 5     2004      0.074      0.027      0.077  0.074      0.072       0.022
#
# City Little Rock Flagstaff Phoenix  ... Bellingham Seattle Spokane Madison  \
# 1           0.09     0.071   0.082  ...      0.052   0.056   0.068   0.072
# 2          0.079     0.068   0.079  ...       0.05   0.051   0.071   0.078
# 3          0.085     0.079   0.082  ...      0.053   0.054   0.071   0.081
# 4          0.075     0.073   0.081  ...      0.056   0.065   0.079   0.078
# 5          0.073     0.072   0.074  ...      0.062   0.062   0.069   0.065
#
# City Milwaukee Wausau Whitewater Charleston Parkersburg Laramie
# 1        0.082  0.073      0.076      0.085       0.087   0.043
# 2        0.094  0.072      0.088      0.083       0.084   0.051
# 3        0.096  0.073      0.084      0.087       0.095   0.044
# 4        0.092  0.074      0.081      0.088       0.083   0.049
# 5        0.073  0.065      0.069      0.069       0.069   0.048
#
# [5 rows x 176 columns]

# %%
#Creating a dash app to display a line chart that shows O3 pollution by year with a dropdown for each city

# Create a Dash app
appO3 = dash.Dash(__name__)


dropdown_options = [{'label': col, 'value': col} for col in city_O3.columns[1:]]

# Define app layout
appO3.layout = html.Div([
    dcc.Dropdown(
        id='dropdown-O3',
        options=dropdown_options,
        value='Birmingham'
    ),
    dcc.Graph(id='line-plot2')
])

# Define callback to update the line plot
@appO3.callback(
    Output('line-plot2', 'figure'),
    [Input('dropdown-O3', 'value')]
)
def update_line_plot(selected_column):
    fig = px.line(city_O3, x='index', y=selected_column)

    title = f'{selected_column} O3'

    fig.update_layout(title=title, xaxis_title = 'Year' ,yaxis_title = 'O3 Concentration')

    return fig

# Run the app
if __name__ == '__main__':
    appO3.run_server(debug=True, port=8052)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8052/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Using the above table, perform a t-test for each state checking for significant difference at the 0.05 significance level for O3 pollution betweeen 1990 and 2022.
#If values return "nan" it means there was only one record for that state, which does not allow for a t-test.

for state in state_O3['State'].unique():
    data_2000 = state_O3.loc[state_O3['State'] == state, '2000']
    data_2022 = state_O3.loc[state_O3['State'] == state, '2022']

    t_statistic, p_value = ttest_ind(data_2000, data_2022)

    print(f'State: {state}')
    print(f't_statistic: {t_statistic}')
    print(f'p_value: {p_value}')
    if p_value < 0.05:
        print('There is a significant difference in O3 pollution between 2000 and 2022')
        if t_statistic > 0:
            print('There was a significant decrease in O3 pollution between 2000 and 2022')
        else:
            print('There was a significant increase in O3 pollution between 2000 and 2022')
            
    else:
        print('No significant difference in O3 pollution between 2000 and 2022')


    print('-------------------------------')
    print('-------------------------------')
# Out:
# State: AL
# t_statistic: 1.4088771121384105
# p_value: 0.19653270107293333
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: AR
# t_statistic: -0.06549461226639136
# p_value: 0.9537378997940775
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: AZ
# t_statistic: 1.9051586888313579
# p_value: 0.10541314582633256
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CA
# t_statistic: 3.0086178285435383
# p_value: 0.004524666556723182
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CO
# t_statistic: -0.4242640687119297
# p_value: 0.6931965033474388
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CT
# t_statistic: 4.035856240405547
# p_value: 0.015657535292376644
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: FL
# t_statistic: 9.535714285714288
# p_value: 1.8467937445058014e-08
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: GA
# t_statistic: 11.799999999999988
# p_value: 0.0071053905545293665
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: HI
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: IL
# t_statistic: 4.47693475329673
# p_value: 0.00420614299167138
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: IN
# t_statistic: -0.4266773537513129
# p_value: 0.6786540865877273
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: KS
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: KY
# t_statistic: 8.520563361656322
# p_value: 6.750733351524476e-06
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: LA
# t_statistic: 11.041933833746906
# p_value: 3.2827296874636774e-05
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MA
# t_statistic: 6.516946235415332
# p_value: 0.0227454502400846
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MD
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: ME
# t_statistic: 2.7854300726557777
# p_value: 0.049542753364461636
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MI
# t_statistic: -0.13922650233796371
# p_value: 0.8920351926413862
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MO
# t_statistic: 2.999999999999993
# p_value: 0.0954659662667095
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MT
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NC
# t_statistic: 19.331582286767777
# p_value: 1.7306909922464942e-13
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: ND
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NE
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NH
# t_statistic: 3.7032803990902066
# p_value: 0.020775715825157057
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NJ
# t_statistic: 0.9184392150683277
# p_value: 0.45534503584162267
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NM
# t_statistic: -0.2626128657194451
# p_value: 0.8174258141649446
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NV
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NY
# t_statistic: 1.2498713019631864
# p_value: 0.23517327220618525
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OH
# t_statistic: 1.9520858747774537
# p_value: 0.06507063152438028
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OK
# t_statistic: 10.285912696499048
# p_value: 0.009319867815919496
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OR
# t_statistic: -0.08058229640253751
# p_value: 0.9396448982122095
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: PA
# t_statistic: 0.982594925436189
# p_value: 0.33486258615476217
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: SC
# t_statistic: 5.277388438354882
# p_value: 0.006181077344966293
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: TN
# t_statistic: 9.669875568304565
# p_value: 7.011690271634063e-05
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: TX
# t_statistic: 5.89862447071615
# p_value: 2.244927393151378e-05
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: UT
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: VA
# t_statistic: 19.23018460649823
# p_value: 0.002693244858166468
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: VT
# t_statistic: 13.000000000000083
# p_value: 0.005865153227565606
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WA
# t_statistic: 0.09480909262799583
# p_value: 0.929026025926628
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WI
# t_statistic: 2.3844195510154944
# p_value: 0.05443894395248785
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WV
# t_statistic: 21.913466179498034
# p_value: 0.002075983140016634
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WY
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_5986/3999496211.py:8: RuntimeWarning:
#
# Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# invalid value encountered in scalar multiply

# %%
#Create a dataframe containing only PM2.5 and continue for each pollutant
pm_2 = ['PM2.5']
pm25_df = mean_2000[mean_2000['Pollutant'].isin(pm_2) == True]
state_pm25 = (pm25_df.groupby(['State', 'City', 'Trend Statistic'], sort=True, as_index=False)[years].sum())
state_pm25
# Out:
#     State         City       Trend Statistic  2000  2001  2002  2003  2004  \
# 0      AK    Anchorage       98th Percentile  20.0  25.0  25.0  23.0  30.0
# 1      AK    Anchorage  Weighted Annual Mean   5.8   6.2   5.8   6.6   6.9
# 2      AK       Juneau       98th Percentile  24.0  26.0  20.0  23.0  26.0
# 3      AK       Juneau  Weighted Annual Mean   6.6   5.6   6.2   6.4   6.6
# 4      AL   Birmingham       98th Percentile  47.0  39.0  36.0  36.0  39.0
# ..    ...          ...                   ...   ...   ...   ...   ...   ...
# 333    WV  Parkersburg  Weighted Annual Mean  17.8  17.4  15.8  14.9  14.9
# 334    WY     Riverton       98th Percentile  33.0  33.0  33.0  26.0  40.0
# 335    WY     Riverton  Weighted Annual Mean   9.6   9.6   9.6   8.1   9.6
# 336    WY     Sheridan       98th Percentile  35.0  40.0  28.0  26.0  39.0
# 337    WY     Sheridan  Weighted Annual Mean  12.1  11.0  10.1  10.1  10.0
#
#      2005  2006  ...  2013  2014  2015  2016  2017  2018  2019  2020  2021  \
# 0    22.0  33.0  ...  22.0  29.0  28.0  23.0  28.0  18.0  35.0  23.0  20.0
# 1     6.7   6.9  ...   5.6   7.0   6.5   6.1   5.6   5.0   7.4   5.3   5.2
# 2    35.0  33.0  ...  23.0  28.0  21.0  24.0  22.0  22.0  25.0  17.0  17.0
# 3     8.1   8.5  ...   5.9   7.7   6.6   6.0   5.6   6.9   6.8   4.8   4.7
# 4    43.0  38.0  ...  21.0  22.0  20.0  17.0  20.0  19.0  18.0  19.0  23.0
# ..    ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 333  16.4  14.7  ...   9.4   9.6   9.3   7.9   8.1   7.7   7.7   7.0   7.9
# 334  30.0  23.0  ...  29.0  26.0  20.0  22.0  27.0  22.0  26.0  37.0  29.0
# 335   7.7   7.7  ...   7.8   6.7   6.2   6.8   7.4   7.3   7.0   7.3   8.5
# 336  33.0  24.0  ...  17.0  19.0  25.0  23.0  25.0  21.0  18.0  34.0  29.0
# 337   9.5   9.7  ...   6.7   6.5   7.5   6.9   7.7   7.2   6.0   6.4   6.5
#
#      2022
# 0    23.0
# 1     4.7
# 2    23.0
# 3     5.3
# 4    19.0
# ..    ...
# 333   7.4
# 334  15.0
# 335   5.8
# 336  29.0
# 337   6.5
#
# [338 rows x 26 columns]

# %%
state_pm25 = state_pm25[state_pm25['Trend Statistic'] != '98th Percentile']
state_pm25
# Out:
#     State         City       Trend Statistic  2000  2001  2002  2003  2004  \
# 1      AK    Anchorage  Weighted Annual Mean   5.8   6.2   5.8   6.6   6.9
# 3      AK       Juneau  Weighted Annual Mean   6.6   5.6   6.2   6.4   6.6
# 5      AL   Birmingham  Weighted Annual Mean  20.0  17.3  16.4  15.7  16.0
# 7      AL       Daphne  Weighted Annual Mean  14.5  10.6  10.4  12.2  11.4
# 9      AL      Decatur  Weighted Annual Mean  13.1  13.1  13.1  13.7  12.2
# ..    ...          ...                   ...   ...   ...   ...   ...   ...
# 329    WV     Fairmont  Weighted Annual Mean  16.0  15.9  15.3  15.0  14.1
# 331    WV   Morgantown  Weighted Annual Mean  15.0  14.9  15.2  14.6  13.8
# 333    WV  Parkersburg  Weighted Annual Mean  17.8  17.4  15.8  14.9  14.9
# 335    WY     Riverton  Weighted Annual Mean   9.6   9.6   9.6   8.1   9.6
# 337    WY     Sheridan  Weighted Annual Mean  12.1  11.0  10.1  10.1  10.0
#
#      2005  2006  ...  2013  2014  2015  2016  2017  2018  2019  2020  2021  \
# 1     6.7   6.9  ...   5.6   7.0   6.5   6.1   5.6   5.0   7.4   5.3   5.2
# 3     8.1   8.5  ...   5.9   7.7   6.6   6.0   5.6   6.9   6.8   4.8   4.7
# 5    18.0  17.3  ...  10.3  10.9  10.3   9.2   9.5   9.0   9.2   8.8   9.8
# 7    11.7  11.2  ...   8.4   8.9   8.6   7.2   7.4   7.1   7.5   7.9   7.3
# 9    13.7  13.2  ...   8.6   9.3   8.8   7.4   7.7   7.4   7.6   7.1   9.0
# ..    ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 329  15.9  14.6  ...   9.3   9.5   9.5   8.6   7.7   7.4   7.6   7.4   7.3
# 331  15.0  13.5  ...   8.9   8.6   8.2   7.4   7.3   6.9   7.2   6.2   7.7
# 333  16.4  14.7  ...   9.4   9.6   9.3   7.9   8.1   7.7   7.7   7.0   7.9
# 335   7.7   7.7  ...   7.8   6.7   6.2   6.8   7.4   7.3   7.0   7.3   8.5
# 337   9.5   9.7  ...   6.7   6.5   7.5   6.9   7.7   7.2   6.0   6.4   6.5
#
#      2022
# 1     4.7
# 3     5.3
# 5     9.2
# 7     7.3
# 9     8.5
# ..    ...
# 329   7.1
# 331   7.0
# 333   7.4
# 335   5.8
# 337   6.5
#
# [169 rows x 26 columns]

# %%
city_pm25 = state_pm25.set_index('City')

# %%
city_pm25.head()
# Out:
#            State       Trend Statistic  2000  2001  2002  2003  2004  2005  \
# City
# Anchorage     AK  Weighted Annual Mean   5.8   6.2   5.8   6.6   6.9   6.7
# Juneau        AK  Weighted Annual Mean   6.6   5.6   6.2   6.4   6.6   8.1
# Birmingham    AL  Weighted Annual Mean  20.0  17.3  16.4  15.7  16.0  18.0
# Daphne        AL  Weighted Annual Mean  14.5  10.6  10.4  12.2  11.4  11.7
# Decatur       AL  Weighted Annual Mean  13.1  13.1  13.1  13.7  12.2  13.7
#
#             2006  2007  ...  2013  2014  2015  2016  2017  2018  2019  2020  \
# City                    ...
# Anchorage    6.9   5.2  ...   5.6   7.0   6.5   6.1   5.6   5.0   7.4   5.3
# Juneau       8.5   6.6  ...   5.9   7.7   6.6   6.0   5.6   6.9   6.8   4.8
# Birmingham  17.3  17.2  ...  10.3  10.9  10.3   9.2   9.5   9.0   9.2   8.8
# Daphne      11.2  10.4  ...   8.4   8.9   8.6   7.2   7.4   7.1   7.5   7.9
# Decatur     13.2  14.4  ...   8.6   9.3   8.8   7.4   7.7   7.4   7.6   7.1
#
#             2021  2022
# City
# Anchorage    5.2   4.7
# Juneau       4.7   5.3
# Birmingham   9.8   9.2
# Daphne       7.3   7.3
# Decatur      9.0   8.5
#
# [5 rows x 25 columns]

# %%
city_pm25.drop(columns=['Trend Statistic'], inplace=True)

# %%
city_pm25.set_index('City', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/jesserinskeys/Desktop/Project3/Data_Analysis.ipynb Cell 29 line 1
# ----> <a href='vscode-notebook-cell:/Users/jesserinskeys/Desktop/Project3/Data_Analysis.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> city_pm25.set_index('City', inplace=True)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:6012, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6009                 missing.append(col)
#    6011 if missing:
# -> 6012     raise KeyError(f"None of {missing} are in the columns")
#    6014 if inplace:
#    6015     frame = self
#
# KeyError: "None of ['City'] are in the columns"

# %%
city_25 = city_pm25.transpose()

# %%
city_25.reset_index(inplace=True)

# %%
city_25 = city_25.drop(index=0)

# %%
city_25.head()
# Out:
# City index Anchorage Juneau Birmingham Daphne Decatur Fort Payne Gadsden  \
# 1     2000       5.8    6.6       20.0   14.5    13.1       17.2    19.5
# 2     2001       6.2    5.6       17.3   10.6    13.1       14.7    17.2
# 3     2002       5.8    6.2       16.4   10.4    13.1       14.4    14.8
# 4     2003       6.6    6.4       15.7   12.2    13.7       15.0    14.3
# 5     2004       6.9    6.6       16.0   11.4    12.2       14.1    14.3
#
# City Huntsville Little Rock  ... Madison Milwaukee Platteville Charleston  \
# 1          16.3        15.5  ...    12.8      13.1        12.3       18.1
# 2          14.6        14.7  ...    13.3      13.8        11.9       18.1
# 3          13.8        13.2  ...    12.3      12.7        10.9       17.1
# 4          13.8        12.9  ...    11.9      12.3        11.3       16.1
# 5          13.4        12.2  ...    11.3      12.0        10.8       15.9
#
# City Clarksburg Fairmont Morgantown Parkersburg Riverton Sheridan
# 1          14.9     16.0       15.0        17.8      9.6     12.1
# 2          14.4     15.9       14.9        17.4      9.6     11.0
# 3          14.0     15.3       15.2        15.8      9.6     10.1
# 4          13.4     15.0       14.6        14.9      8.1     10.1
# 5          13.3     14.1       13.8        14.9      9.6     10.0
#
# [5 rows x 170 columns]

# %%
#Creating a dash app to display a line chart that shows PM2.5 pollution by year with a dropdown for each city

# Create a Dash app
appPM25 = dash.Dash(__name__)


dropdown_options = [{'label': col, 'value': col} for col in city_25.columns[2:]]

# Define app layout
appPM25.layout = html.Div([
    dcc.Dropdown(
        id='dropdown-PM25',
        options=dropdown_options,
        value='Anchorage'
    ),
    dcc.Graph(id='line-plot3')
])

# Define callback to update the line plot
@appPM25.callback(
    Output('line-plot3', 'figure'),
    [Input('dropdown-PM25', 'value')]
)
def update_line_plot(selected_column):
    fig = px.line(city_25, x='index', y=selected_column)

    title = f'{selected_column} PM2.5'

    fig.update_layout(title = title, xaxis_title = 'Year', yaxis_title = 'PM2.5 Concentration')

    return fig

# Run the app
if __name__ == '__main__':
    appPM25.run_server(debug=True, port=8053)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8053/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Using the above table, perform a t-test for each state checking for significant difference at the 0.05 significance level of PM2.5 pollution between 2000 and 2022.
#If values return "nan" it means there was only one record for that state, which does not allow for a t-test.

for state in state_pm25['State'].unique():
    data_2000 = state_pm25.loc[state_pm25['State'] == state, '2000']
    data_2022 = state_pm25.loc[state_pm25['State'] == state, '2022']

    t_statistic, p_value = ttest_ind(data_2000, data_2022)

    print(f'State: {state}')
    print(f't_statistic: {t_statistic}')
    print(f'p_value: {p_value}')
    if p_value < 0.05:
        print('There is a significant difference in PM2.5 pollution between 2000 and 2022')
        if t_statistic > 0:
            print('There was a significant decrease in PM2.5 pollution between 2000 and 2022')
        else:
            print('There was a significant increase in PM2.5 pollution between 2000 and 2022')
            
    else:
        print('No significant difference in PM2.5 pollution between 2000 and 2022')


    print('-------------------------------')
# Out:
# State: AK
# t_statistic: 2.3999999999999995
# p_value: 0.1384502096587143
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: AL
# t_statistic: 7.601710220633044
# p_value: 1.8364299284931228e-05
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: AR
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: AZ
# t_statistic: 1.1214296958515246
# p_value: 0.32487611072332695
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: CA
# t_statistic: 2.8265393387646105
# p_value: 0.007175150014392773
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: CO
# t_statistic: 7.003859939637153
# p_value: 0.0004222184586947569
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: CT
# t_statistic: 5.394583842040787
# p_value: 0.00571278093531635
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: DE
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: FL
# t_statistic: 6.246975400302782
# p_value: 4.228399554832331e-06
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: GA
# t_statistic: 8.743929933365866
# p_value: 1.4959837659471997e-06
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: HI
# t_statistic: 2.630383796885715
# p_value: 0.11922898789891165
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: IA
# t_statistic: 6.424951361683604
# p_value: 0.000671595352770918
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: IN
# t_statistic: 9.58743729785981
# p_value: 5.63512481499538e-07
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: KS
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: KY
# t_statistic: 13.247641299491775
# p_value: 0.0001876191319635189
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: LA
# t_statistic: 15.06978397998156
# p_value: 3.343745101244018e-08
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: MA
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: MD
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: MI
# t_statistic: 6.388014259386023
# p_value: 3.4633684270091034e-05
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: MN
# t_statistic: 9.4528533069949
# p_value: 0.011006710173425985
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: MO
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: MT
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NC
# t_statistic: 11.292651166934608
# p_value: 9.487606114188256e-08
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: ND
# t_statistic: -0.7913267865219099
# p_value: 0.5116939255093911
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NE
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NH
# t_statistic: 1.819221943661682
# p_value: 0.21049284058324197
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NJ
# t_statistic: 3.8077703507758685
# p_value: 0.06256660109273532
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NM
# t_statistic: 1.0427120034542843
# p_value: 0.4065575739437923
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NV
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NY
# t_statistic: 5.624945069164025
# p_value: 0.0004956364635581505
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: OH
# t_statistic: 9.44471305420504
# p_value: 6.045534076757854e-08
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: OK
# t_statistic: 3.8011246773376053
# p_value: 0.019085187356128363
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: OR
# t_statistic: -0.08622939374702118
# p_value: 0.935427940695366
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: PA
# t_statistic: 10.379730969247413
# p_value: 5.017522475001141e-09
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: PR
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: SC
# t_statistic: 5.883484054145521
# p_value: 0.02769441467175341
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: TX
# t_statistic: 2.76112224176952
# p_value: 0.02463204243154619
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: UT
# t_statistic: 2.1828206253269973
# p_value: 0.16074567258371752
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: VA
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: VT
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: WA
# t_statistic: 3.1304951684997047
# p_value: 0.08867762313423297
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: WI
# t_statistic: 10.911322268285554
# p_value: 4.41028065622218e-06
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: WV
# t_statistic: 13.42734240159691
# p_value: 9.065544860186981e-07
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: WY
# t_statistic: 3.6207447141253226
# p_value: 0.06853045853493385
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_5986/1694952570.py:8: RuntimeWarning:
#
# Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# invalid value encountered in scalar multiply

# %%
SO2 = ['SO2']
SO2_df = mean_2000[mean_2000['Pollutant'].isin(SO2) == True]
state_SO2 = (SO2_df.groupby(['State', 'City'], sort=True, as_index=False)[years].sum())
state_SO2.head()
# Out:
#   State           City   2000  2001   2002  2003  2004  2005  2006  2007  ...  \
# 0    AL     Birmingham  149.0  63.0   50.0  53.0  56.0  70.0  70.0  50.0  ...
# 1    CA  San Francisco   20.0  21.0   20.0  15.0  20.0  16.0  22.0  18.0  ...
# 2    CA    Santa Maria    4.0   8.0    7.0   5.0  11.0   7.0   5.0   5.0  ...
# 3    CO         Denver   65.0  73.0   73.0  58.0  40.0  39.0  33.0  30.0  ...
# 4    FL   Jacksonville  107.0  99.0  100.0  68.0  80.0  90.0  94.0  53.0  ...
#
#    2013  2014  2015  2016  2017  2018  2019  2020  2021  2022
# 0  22.0  17.0  17.0  11.0  12.0  11.0  10.0   5.0   7.0   6.0
# 1   9.0  12.0   8.0   9.0   9.0  10.0  10.0   8.0   9.0   7.0
# 2   3.0   4.0   2.0   2.0   1.0   2.0   3.0   3.0   2.0   2.0
# 3  34.0  16.0  15.0  14.0  13.0   7.0   6.0   6.0   6.0   5.0
# 4  33.0  37.0  27.0  25.0  20.0  22.0  24.0  28.0  20.0  20.0
#
# [5 rows x 25 columns]

# %%
#Using the above table, perform a t-test for each state checking for significant difference at the 0.05 significance level between SO2 pollution in 1990 and 2022. 
#If values return "nan" it means there was only one record for that state, which does not allow for a t-test.

for state in state_SO2['State'].unique():
    data_2000 = state_SO2.loc[state_SO2['State'] == state, '2000']
    data_2022 = state_SO2.loc[state_SO2['State'] == state, '2022']

    t_statistic, p_value = ttest_ind(data_2000, data_2022)

    print(f'State: {state}')
    print(f't_statistic: {t_statistic}')
    print(f'p_value: {p_value}')
    if p_value < 0.05:
        print('There is a significant difference in SO2 pollution between 2000 and 2022')
        if t_statistic > 0:
            print('There was a significant decrease in SO2 pollution between 2000 and 2022')
        else:
            print('There was a significant increase in SO2 pollution between 2000 and 2022')
            
    else:
        print('No significant difference in SO2 pollution between 2000 and 2022')


    print('-------------------------------')
    print('-------------------------------')
# Out:
# State: AL
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CA
# t_statistic: 0.8948249794078403
# p_value: 0.4653077456503607
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CO
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: FL
# t_statistic: 2.3408832387529346
# p_value: 0.04127736090068851
# There is a significant difference in SO2 pollution between 2000 and 2022
# There was a significant decrease in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: GA
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: HI
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: IA
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: IL
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: IN
# t_statistic: 10.15333012566818
# p_value: 0.0005298359203691353
# There is a significant difference in SO2 pollution between 2000 and 2022
# There was a significant decrease in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: KY
# t_statistic: 4.314554973040049
# p_value: 0.04974473186050386
# There is a significant difference in SO2 pollution between 2000 and 2022
# There was a significant decrease in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: LA
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MA
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MI
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MO
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MT
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NC
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: ND
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NY
# t_statistic: 3.0084541518836927
# p_value: 0.03961060266577003
# There is a significant difference in SO2 pollution between 2000 and 2022
# There was a significant decrease in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OH
# t_statistic: 2.357249189874626
# p_value: 0.07789635737091061
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OK
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: PA
# t_statistic: 4.892566218435647
# p_value: 0.0012050411278317148
# There is a significant difference in SO2 pollution between 2000 and 2022
# There was a significant decrease in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: TX
# t_statistic: 2.0497571673129946
# p_value: 0.10972054781854519
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: VA
# t_statistic: 1.553323788268816
# p_value: 0.26055795149966565
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: VT
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WI
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WV
# t_statistic: 32.83115830658755
# p_value: 0.0009264537265869911
# There is a significant difference in SO2 pollution between 2000 and 2022
# There was a significant decrease in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_5986/1611401142.py:8: RuntimeWarning:
#
# Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# invalid value encountered in scalar multiply

# %%
NO2 = ['NO2']
NO2_df = mean_2000[mean_2000['Pollutant'].isin(NO2) == True]
NO2_df
# Out:
#      Primary Key   CBSA         City State Pollutant  Trend Statistic  \
# 10            11  10740  Albuquerque    NM       NO2      Annual Mean
# 11            12  10740  Albuquerque    NM       NO2  98th Percentile
# 35            36  12060      Atlanta    GA       NO2      Annual Mean
# 44            45  12540  Bakersfield    CA       NO2      Annual Mean
# 45            46  12540  Bakersfield    CA       NO2  98th Percentile
# ..           ...    ...          ...   ...       ...              ...
# 695          696  49180      Winston    NC       NO2  98th Percentile
# 702          703  49620         York    PA       NO2      Annual Mean
# 703          704  49620         York    PA       NO2  98th Percentile
# 708          709  49700    Yuba City    CA       NO2      Annual Mean
# 709          710  49700    Yuba City    CA       NO2  98th Percentile
#
#      Number of Sites  2000  2001  2002  ...  2013  2014  2015  2016  2017  \
# 10                 1  17.0  17.0  19.0  ...  12.0  12.0  11.0  10.0  10.0
# 11                 1  55.0  54.0  57.0  ...  45.0  42.0  43.0  44.0  45.0
# 35                 1  18.0  17.0  15.0  ...   9.0  11.0  10.0  11.0   9.0
# 44                 2  15.0  16.0  16.0  ...  10.0   9.0   8.0   8.0   7.0
# 45                 2  52.0  56.0  55.0  ...  42.0  41.0  35.0  32.0  33.0
# ..               ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 695                1  59.0  59.0  52.0  ...  37.0  41.0  39.0  36.0  38.0
# 702                1  18.0  20.0  17.0  ...  10.0  11.0  10.0  10.0   8.0
# 703                1  65.0  66.0  63.0  ...  39.0  45.0  52.0  47.0  42.0
# 708                1  13.0  14.0  15.0  ...  10.0   8.0   7.0   7.0   7.0
# 709                1  67.0  64.0  62.0  ...  52.0  44.0  39.0  40.0  42.0
#
#      2018  2019  2020  2021  2022
# 10   10.0   9.0   8.0   8.0   9.0
# 11   45.0  44.0  41.0  44.0  44.0
# 35    8.0   9.0   8.0   8.0   8.0
# 44    8.0   7.0   7.0   7.0   7.0
# 45   33.0  34.0  30.0  30.0  29.0
# ..    ...   ...   ...   ...   ...
# 695  35.0  34.0  30.0  32.0  35.0
# 702   6.0   7.0   7.0   8.0   9.0
# 703  41.0  40.0  39.0  40.0  39.0
# 708   7.0   6.0   6.0   5.0   7.0
# 709  41.0  40.0  38.0  34.0  37.0
#
# [87 rows x 30 columns]

# %%
CO = ['CO']
CO_df = mean_2000[mean_2000['Pollutant'].isin(CO) == True]
state_CO = (CO_df.groupby(['State', 'City'], sort=True, as_index=False)[years].sum())
state_CO
# Out:
#    State            City  2000  2001  2002  2003  2004  2005  2006  2007  ...  \
# 0     AK       Anchorage   5.4   5.7   4.7   5.7   6.4   4.8   4.3   3.6  ...
# 1     AL      Birmingham   3.7   6.3   3.7   3.1   3.9   2.5   3.1   2.0  ...
# 2     AZ         Phoenix   5.2   4.5   4.4   3.8   3.4   3.6   3.3   3.0  ...
# 3     AZ          Tucson   4.7   2.9   2.5   2.6   2.0   2.1   1.8   1.9  ...
# 4     CA          Fresno   3.3   2.8   2.5   1.8   1.7   1.8   2.1   1.7  ...
# 5     CA     Los Angeles   5.3   3.9   3.5   3.4   2.9   2.6   2.5   2.1  ...
# 6     CA       Riverside   2.6   2.2   2.1   2.4   1.8   1.6   1.5   1.5  ...
# 7     CA      Sacramento   4.6   5.0   3.5   3.8   2.8   3.3   3.0   2.8  ...
# 8     CA   San Francisco   2.7   2.8   2.2   2.1   1.8   1.7   1.7   1.6  ...
# 9     CA     Santa Maria   1.1   1.1   1.2   1.0   0.9   0.8   1.3   1.1  ...
# 10    CA         Vallejo   5.0   4.1   3.7   2.9   3.1   3.0   2.7   2.6  ...
# 11    CO          Denver   4.2   3.7   3.2   3.8   3.5   2.4   2.8   2.5  ...
# 12    CO    Fort Collins   3.8   3.0   2.9   2.5   3.1   2.4   2.7   2.4  ...
# 13    FL           Miami   3.2   4.0   3.4   3.0   5.3   2.5   2.2   2.0  ...
# 14    FL         Orlando   2.4   2.0   2.5   1.5   1.6   1.8   1.5   1.0  ...
# 15    HI  Urban Honolulu   1.4   1.5   1.6   1.1   1.0   1.1   0.9   0.8  ...
# 16    LA     Baton Rouge   3.6   4.8   3.7   3.1   2.7   2.1   3.3   1.6  ...
# 17    MI         Detroit   3.3   1.6   3.7   2.4   2.3   1.7   2.3   1.4  ...
# 18    MI    Grand Rapids   2.6   3.1   2.8   2.0   1.8   1.9   2.0   1.1  ...
# 19    NM     Albuquerque   3.3   2.9   2.8   2.1   2.2   2.0   2.0   1.6  ...
# 20    NV            Reno   5.2   4.6   4.4   3.8   3.9   3.2   3.0   3.1  ...
# 21    NY         Buffalo   2.0   1.9   1.8   2.4   1.4   1.6   1.7   1.1  ...
# 22    NY        New York   4.3   3.9   3.6   3.1   3.3   3.1   2.7   2.2  ...
# 23    OH       Cleveland   7.9   2.8   2.0   2.7   5.4   2.9   3.9   2.9  ...
# 24    OR        Portland   3.8   3.2   3.0   3.1   3.7   2.5   2.7   2.7  ...
# 25    PA       Johnstown   2.0   2.1   2.6   2.2   2.1   1.2   1.5   1.9  ...
# 26    PA        Scranton   2.1   1.8   1.6   1.5   1.8   1.5   1.4   1.5  ...
# 27    TX         Houston   2.6   2.3   2.8   4.2   1.8   1.7   1.8   1.5  ...
# 28    VT         Rutland   2.5   2.2   2.3   1.9   1.8   1.8   1.4   1.7  ...
#
#     2013  2014  2015  2016  2017  2018  2019  2020  2021  2022
# 0    3.1   2.5   2.8   3.0   3.5   2.7   2.4   3.0   2.2   2.4
# 1    1.7   2.4   1.9   1.4   1.0   1.2   1.2   1.1   1.0   0.8
# 2    2.0   2.1   1.9   1.9   2.2   2.0   1.7   1.9   1.9   1.7
# 3    1.1   1.0   1.0   0.9   1.0   0.8   0.6   0.8   0.7   0.7
# 4    1.4   1.1   1.0   1.3   1.2   1.3   1.0   2.2   1.1   1.0
# 5    1.7   1.6   1.6   1.3   1.5   1.4   1.3   1.5   1.4   1.2
# 6    1.2   1.6   1.1   1.3   1.0   1.0   0.7   1.1   1.0   0.9
# 7    2.1   1.7   1.9   1.7   1.6   3.3   1.2   2.0   1.1   1.1
# 8    1.2   1.2   1.1   1.0   1.2   1.6   0.9   1.6   0.9   0.9
# 9    0.6   0.6   0.5   3.2   1.3   0.7   0.5   0.7   0.6   0.6
# 10   2.0   2.0   1.8   1.8   1.9   2.1   1.5   1.7   1.6   1.6
# 11   2.3   1.9   1.9   1.6   1.4   2.1   1.5   1.5   1.4   1.4
# 12   1.4   1.4   1.4   1.3   1.2   1.6   1.3   1.1   1.0   1.1
# 13   1.0   1.3   1.1   1.0   1.1   1.1   1.2   0.9   1.1   1.1
# 14   1.0   1.5   1.2   1.2   1.4   1.0   0.7   0.9   0.9   0.9
# 15   1.1   1.2   1.3   1.2   1.0   1.6   0.6   0.5   0.6   0.6
# 16   1.8   1.3   1.2   1.1   1.0   1.7   0.9   0.8   0.9   0.9
# 17   1.1   1.1   1.1   1.1   1.6   1.6   1.4   1.2   1.3   1.1
# 18   1.0   0.9   1.2   0.9   1.0   0.9   1.3   1.1   1.1   1.2
# 19   0.9   1.2   1.4   1.2   1.0   1.0   1.0   0.9   0.8   0.9
# 20   2.4   2.4   2.0   1.9   2.2   1.6   1.5   1.8   2.0   1.8
# 21   1.3   1.3   1.5   0.9   1.0   0.7   0.7   0.8   0.7   0.7
# 22   1.8   2.0   1.7   2.0   1.4   2.2   1.4   1.8   1.8   1.8
# 23   4.6   3.7   2.9   3.9   3.3   3.1   2.3   2.2   2.1   2.5
# 24   1.8   1.3   1.9   1.2   1.1   1.6   1.4  14.1   1.4   1.5
# 25   1.6   1.2   1.1   0.7   0.6   1.0   1.3   0.9   0.6   1.1
# 26   1.3   1.0   1.2   0.9   0.7   1.0   0.8   0.8   0.9   0.9
# 27   1.1   1.1   1.0   1.0   0.9   1.2   1.3   1.0   1.3   1.3
# 28   1.3   0.9   1.4   0.7   0.7   0.9   1.0   0.8   0.6   0.8
#
# [29 rows x 25 columns]

# %%
#Using the above table, perform a t-test for each state checking for significant difference at the 0.05 significance level between CO pollution in 1990 and 2022. 
#If values return "nan" it means there was only one record for that state, which does not allow for a t-test.

for state in state_CO['State'].unique():
    data_2000 = state_CO.loc[state_CO['State'] == state, '2000']
    data_2022 = state_CO.loc[state_CO['State'] == state, '2022']

    t_statistic, p_value = ttest_ind(data_2000, data_2022)

    print(f'State: {state}')
    print(f't_statistic: {t_statistic}')
    print(f'p_value: {p_value}')
    if p_value < 0.05:
        print('There is a significant difference in CO pollution between 2000 and 2022')
        if t_statistic > 0:
            print('There was a significant decrease in CO pollution between 2000 and 2022')
        else:
            print('There was a significant increase in CO pollution between 2000 and 2022')
            
    else:
        print('No significant difference in CO pollution between 2000 and 2022')


    print('-------------------------------')
    print('-------------------------------')
# Out:
# State: AK
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: AL
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: AZ
# t_statistic: 6.7082039324993685
# p_value: 0.02150789041983671
# There is a significant difference in CO pollution between 2000 and 2022
# There was a significant decrease in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CA
# t_statistic: 4.2024635912800745
# p_value: 0.0012265180738523498
# There is a significant difference in CO pollution between 2000 and 2022
# There was a significant decrease in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CO
# t_statistic: 10.999999999999998
# p_value: 0.008163401865824484
# There is a significant difference in CO pollution between 2000 and 2022
# There was a significant decrease in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: FL
# t_statistic: 4.365641250653992
# p_value: 0.04867043935295808
# There is a significant difference in CO pollution between 2000 and 2022
# There was a significant decrease in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: HI
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: LA
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MI
# t_statistic: 5.091168824543145
# p_value: 0.036482090370059346
# There is a significant difference in CO pollution between 2000 and 2022
# There was a significant decrease in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NM
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NV
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NY
# t_statistic: 1.4904826270501987
# p_value: 0.27457662909484803
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OH
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OR
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: PA
# t_statistic: 9.391485505499112
# p_value: 0.011148620369176666
# There is a significant difference in CO pollution between 2000 and 2022
# There was a significant decrease in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: TX
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: VT
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_5986/1731307579.py:8: RuntimeWarning:
#
# Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# invalid value encountered in scalar multiply

# %%
pm10 = ['PM10']
pm10_df = mean_2000[mean_2000['Pollutant'].isin(pm10) == True]
pm10_df.head()
# Out:
#      Primary Key   CBSA         City State Pollutant Trend Statistic  \
# 13            14  10740  Albuquerque    NM      PM10         2nd Max
# 73            74  13820   Birmingham    AL      PM10         2nd Max
# 84            85  14500      Boulder    CO      PM10         2nd Max
# 113          114  16700   Charleston    SC      PM10         2nd Max
# 122          123  17460    Cleveland    OH      PM10         2nd Max
#
#      Number of Sites   2000  2001  2002  ...  2013   2014  2015  2016  2017  \
# 13                 1   35.0  41.0  63.0  ...  92.0  106.0  44.0  63.0  46.0
# 73                 1  101.0  64.0  42.0  ...  32.0   32.0  64.0  35.0  28.0
# 84                 1   68.0  47.0  41.0  ...  44.0   55.0  42.0  41.0  38.0
# 113                1   52.0  63.0  39.0  ...  34.0   30.0  39.0  66.0  29.0
# 122                4   63.0  66.5  58.8  ...  37.3   33.5  35.8  44.5  35.3
#
#      2018  2019  2020  2021   2022
# 13   60.0  49.0  67.0  85.0  100.0
# 73   29.0  28.0  28.0  28.0   28.0
# 84   57.0  50.0  65.0  51.0   39.0
# 113  31.0  54.0  45.0  40.0   53.0
# 122  38.3  37.3  30.9  33.5   38.5
#
# [5 rows x 30 columns]

# %%
#create a dataframe summing the total pollutants in each city by year
city_total_df = (mean_2000.groupby('City', sort=True, as_index=False)[years].sum())

# %%
#Convert list of cities to be used in a dropdown menu for future plots
city_list = city_total_df['City'].tolist()

# %%
#Set index to prepare for dataframe inversion
city_total_df.set_index('City', inplace=True)

# %%
city_total_df.head()
# Out:
#                 2000     2001     2002     2003     2004     2005     2006  \
# City
# Akron        216.285  192.296  201.100  215.190  220.879  198.791  181.874
# Albany        97.070   93.989   89.991   86.381   93.175   98.282   90.270
# Albuquerque  136.972  140.371  166.174  167.076  126.071  154.073  133.671
# Altoona       62.080   68.083   51.089   62.083   61.073   72.077   48.071
# Americus       0.092    0.082    0.070    0.072    0.070    0.071    0.077
#
#                 2007     2008     2009  ...     2013     2014     2015  \
# City                                    ...
# Akron         91.187   79.975   68.767  ...   56.759   52.960   47.465
# Albany        99.178   80.378   75.166  ...   63.163   59.561   57.862
# Albuquerque  140.369  131.164  114.663  ...  171.667  185.662  127.066
# Altoona       56.071   55.075   51.065  ...   29.065   30.060   31.069
# Americus       0.076    0.068    0.060  ...    0.060    0.059    0.057
#
#                 2016     2017     2018     2019     2020     2021     2022
# City
# Akron         33.260   28.966   31.968   32.262   32.963   33.067   30.170
# Albany        53.068   56.361   56.966   54.355   61.954   65.661   49.059
# Albuquerque  141.665  122.669  136.174  124.067  141.271  160.571  174.371
# Altoona       13.062    7.063    8.064    8.064    4.063    4.061    6.062
# Americus       0.065    0.058    0.062    0.062    0.054    0.059    0.059
#
# [5 rows x 23 columns]

# %%
#Transposing the dataframe
cities_df = city_total_df.transpose()
cities_df.head()
# Out:
# City    Akron  Albany  Albuquerque  Altoona  Americus  Anchorage  Ann Arbor  \
# 2000  216.285  97.070      136.972   62.080     0.092       31.2     44.335
# 2001  192.296  93.989      140.371   68.083     0.082       36.9     54.431
# 2002  201.100  89.991      166.174   51.089     0.070       35.5     45.930
# 2003  215.190  86.381      167.076   62.083     0.072       35.3     53.634
# 2004  220.879  93.175      126.071   61.073     0.070       43.3     44.724
#
# City  Appleton  Arkadelphia  Asheville  ...  Washington Court House  \
# 2000      43.5        0.029     49.490  ...                   0.024
# 2001      44.1        0.021     44.576  ...                   0.022
# 2002      39.8        0.031     44.890  ...                   0.020
# 2003      36.4        0.032     43.670  ...                   0.020
# 2004      38.7        0.022     39.373  ...                   0.024
#
# City  Watertown  Wausau  Whitewater  Wichita  Wilmington  Winston  Yakima  \
# 2000      0.072   0.073       0.076   36.280       0.080  196.489    48.5
# 2001      0.102   0.072       0.088   33.984       0.078  201.194    48.5
# 2002      0.100   0.073       0.084   36.379       0.080  221.093    45.2
# 2003      0.089   0.074       0.081   34.680       0.076  191.581    45.2
# 2004      0.071   0.065       0.069   34.368       0.070  203.078    54.9
#
# City     York  Yuba City
# 2000  218.790    128.679
# 2001  191.787    143.981
# 2002  208.901    124.180
# 2003  189.481    114.576
# 2004  230.477    112.073
#
# [5 rows x 236 columns]

# %%
#reset the index
cities_df.reset_index(inplace=True)

# %%
cities_df.head()
# Out:
# City index    Akron  Albany  Albuquerque  Altoona  Americus  Anchorage  \
# 0     2000  216.285  97.070      136.972   62.080     0.092       31.2
# 1     2001  192.296  93.989      140.371   68.083     0.082       36.9
# 2     2002  201.100  89.991      166.174   51.089     0.070       35.5
# 3     2003  215.190  86.381      167.076   62.083     0.072       35.3
# 4     2004  220.879  93.175      126.071   61.073     0.070       43.3
#
# City  Ann Arbor  Appleton  Arkadelphia  ...  Washington Court House  \
# 0        44.335      43.5        0.029  ...                   0.024
# 1        54.431      44.1        0.021  ...                   0.022
# 2        45.930      39.8        0.031  ...                   0.020
# 3        53.634      36.4        0.032  ...                   0.020
# 4        44.724      38.7        0.022  ...                   0.024
#
# City  Watertown  Wausau  Whitewater  Wichita  Wilmington  Winston  Yakima  \
# 0         0.072   0.073       0.076   36.280       0.080  196.489    48.5
# 1         0.102   0.072       0.088   33.984       0.078  201.194    48.5
# 2         0.100   0.073       0.084   36.379       0.080  221.093    45.2
# 3         0.089   0.074       0.081   34.680       0.076  191.581    45.2
# 4         0.071   0.065       0.069   34.368       0.070  203.078    54.9
#
# City     York  Yuba City
# 0     218.790    128.679
# 1     191.787    143.981
# 2     208.901    124.180
# 3     189.481    114.576
# 4     230.477    112.073
#
# [5 rows x 237 columns]

# %%
##Creating a dash app to display a line chart that shows overall pollution by year with a dropdown for each state

# Create a Dash app
app = dash.Dash(__name__)


dropdown_options = [{'label': col, 'value': col} for col in cities_df.columns[1:]]

# Define app layout
app.layout = html.Div([
    dcc.Dropdown(
        id='dropdown-column',
        options=dropdown_options,
        value='Akron'
    ),
    dcc.Graph(id='line-plot')
])

# Define callback to update the line plot
@app.callback(
    Output('line-plot', 'figure'),
    [Input('dropdown-column', 'value')]
)
def update_line_plot(selected_column):
    fig = px.line(cities_df, x='index', y=selected_column)

    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True, port = 8050)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# The following will include some statistics found from these above data starting with the state level.

# %%
state_avg.reset_index(inplace=True)

# %%
#What are the best and worst states for pollution?
lowest_pollutant = state_avg['2022'].min()
best_state = state_avg.loc[state_avg['2022'].idxmin(), 'State']
print(f'{best_state} is the state with the lowest overall pollution concentration with a pollutant density value of {lowest_pollutant}.')

most_pollutant = state_avg['2022'].max()
worst_state = state_avg.loc[state_avg['2022'].idxmax(), 'State']
print(f'{worst_state} is the state with the highest overall pollution concentration with a pollutant density value of {most_pollutant}.')
# Out:
# ME is the state with the lowest overall pollution concentration with a pollutant density value of 0.057666666666666665.
# OR is the state with the highest overall pollution concentration with a pollutant density value of 145.52075.

# %%
#Which states improved and deproved over time the most in pollution concentration?

state_avg['Change_Over_Time'] = state_avg['2022'] - state_avg['2000']

best_change = state_avg['Change_Over_Time'].min()
best_change_state = state_avg.loc[state_avg['Change_Over_Time'].idxmin(), 'State']
print(f'{best_change_state} is the state with the best overall pollution change over time with a pollutant density change of {best_change}.')


worst_change = state_avg['Change_Over_Time'].max()
worst_change_state = state_avg.loc[state_avg['Change_Over_Time'].idxmax(), 'State']
print(f'{worst_change_state} is the state with the worst overall pollution change over time with a pollutant density change of {worst_change}.')
# Out:
# WV is the state with the best overall pollution change over time with a pollutant density change of -99.66980000000001.
# OR is the state with the worst overall pollution change over time with a pollutant density change of 91.85024999999999.

# %% [markdown]
# The following will take a look at the same statistics at the city level.

# %%
city_total_df.reset_index(inplace=True)

# %%
#What are the best and worst cities for pollution?
low_pollutant = city_total_df['2022'].min()
best_city = city_total_df.loc[city_total_df['2022'].idxmin(), 'City']
print(f'{best_city} is the city with the lowest overall pollution concentration with a value of {low_pollutant}.')

high_pollutant = city_total_df['2022'].max()
worst_city = city_total_df.loc[city_total_df['2022'].idxmax(), 'City']
print(f'{worst_city} is the city with the highest pollution concentration with a value of {high_pollutant}.')
# Out:
# Bellingham is the city with the lowest overall pollution concentration with a value of 0.048.
# Eugene is the city with the highest pollution concentration with a value of 506.758.

# %%
#Which cities improved and deproved over time the most in pollution concentration?

city_total_df['Change_Over_Time'] = city_total_df['2022'] - city_total_df['2000']

best_change_c = city_total_df['Change_Over_Time'].min()
best_change_city = city_total_df.loc[city_total_df['Change_Over_Time'].idxmin(), 'City']
print(f'{best_change_city} is the city with the best overall pollution change over time with a pollutant density change of {best_change_c}.')


worst_change_c = city_total_df['Change_Over_Time'].max()
worst_change_city = city_total_df.loc[city_total_df['Change_Over_Time'].idxmax(), 'City']
print(f'{worst_change_city} is the city with the worst overall pollution change over time with a pollutant density change of {worst_change_c}.')
# Out:
# Birmingham is the city with the best overall pollution change over time with a pollutant density change of -257.727.
# Eugene is the city with the worst overall pollution change over time with a pollutant density change of 380.402.

# %% [markdown]
# Now we will take a look at some statistics at the individual pollutant level.

# %%
#Summary statistics by each year for O3 concentration by state.
O3_avg.describe()
# Out:
#             2000       2001       2002       2003       2004       2005  \
# count  42.000000  42.000000  42.000000  42.000000  42.000000  42.000000
# mean    0.073771   0.074851   0.078600   0.073609   0.067585   0.072209
# std     0.012556   0.013507   0.014898   0.010678   0.009215   0.012046
# min     0.043000   0.042000   0.043000   0.038000   0.046000   0.038000
# 25%     0.067167   0.070116   0.072875   0.070813   0.064429   0.066900
# 50%     0.075125   0.078875   0.079833   0.075292   0.069000   0.074000
# 75%     0.083500   0.082625   0.087810   0.081179   0.072950   0.079750
# max     0.095000   0.099333   0.106333   0.093000   0.082000   0.093333
#
#             2006       2007       2008       2009  ...       2013       2014  \
# count  42.000000  42.000000  42.000000  42.000000  ...  42.000000  42.000000
# mean    0.071190   0.070748   0.067098   0.063244  ...   0.064828   0.064436
# std     0.010641   0.012500   0.009695   0.007225  ...   0.006249   0.004877
# min     0.040000   0.033000   0.041000   0.046500  ...   0.047000   0.052000
# 25%     0.066625   0.065411   0.063354   0.061232  ...   0.062025   0.061714
# 50%     0.071750   0.074381   0.068333   0.064000  ...   0.065500   0.064417
# 75%     0.078500   0.078250   0.073292   0.067562  ...   0.068202   0.067938
# max     0.092000   0.091333   0.084000   0.074750  ...   0.082667   0.074000
#
#             2015       2016       2017       2018       2019       2020  \
# count  42.000000  42.000000  42.000000  42.000000  42.000000  42.000000
# mean    0.065622   0.065211   0.065290   0.066836   0.062243   0.061393
# std     0.005427   0.006716   0.005681   0.005890   0.005340   0.007371
# min     0.048000   0.047000   0.046000   0.046000   0.051000   0.044000
# 25%     0.063100   0.063625   0.062500   0.063725   0.059083   0.056542
# 50%     0.065000   0.065417   0.064583   0.067125   0.062650   0.059714
# 75%     0.068375   0.069000   0.067944   0.069875   0.064917   0.065812
# max     0.079667   0.079000   0.078333   0.080000   0.079000   0.080000
#
#             2021       2022
# count  42.000000  42.000000
# mean    0.064952   0.063329
# std     0.006631   0.006182
# min     0.045000   0.044000
# 25%     0.061083   0.061000
# 50%     0.063500   0.062625
# 75%     0.067667   0.067125
# max     0.082000   0.075333
#
# [8 rows x 23 columns]

# %%
# Which states have the lowest and highest O3 concentration?
low_O3 = O3_avg['2022'].min()
best_state_O3 = O3_avg.loc[O3_avg['2022'].idxmin(), 'State']
print(f'{best_state_O3} is the state with the lowest concentration of O3 with a value of {low_O3}')

high_O3 = O3_avg['2022'].max()
worst_state_O3 = O3_avg.loc[O3_avg['2022'].idxmax(), 'State']
print(f'{worst_state_O3} is the state with the highest concentration of O3 with a value of {high_O3}')
# Out:
# HI is the state with the lowest concentration of O3 with a value of 0.044
# CT is the state with the highest concentration of O3 with a value of 0.07533333333333332

# %%
#Summary statistics of PM25 concentration for each year by city.
city_pm25.describe()
# Out:
#              2000        2001        2002        2003        2004        2005  \
# count  169.000000  169.000000  169.000000  169.000000  169.000000  169.000000
# mean    13.040828   12.675740   12.399408   11.859172   11.466864   12.362722
# std      3.607275    3.372605    3.397539    2.993453    2.873353    3.314969
# min      4.200000    4.200000    4.000000    3.700000    3.400000    3.800000
# 25%     10.900000   10.700000   10.300000    9.700000    9.700000   10.300000
# 50%     13.100000   12.700000   12.700000   12.000000   11.600000   12.800000
# 75%     15.600000   14.800000   14.500000   14.000000   13.500000   14.600000
# max     23.900000   22.500000   23.200000   18.200000   18.100000   18.900000
#
#              2006        2007        2008        2009  ...        2013  \
# count  169.000000  169.000000  169.000000  169.000000  ...  169.000000
# mean    11.404142   11.579882   10.651479    9.688757  ...    8.839645
# std      2.806060    3.140662    2.649688    2.354894  ...    2.360721
# min      3.500000    4.000000    4.400000    3.800000  ...    4.700000
# 25%      9.300000    9.600000    9.100000    8.300000  ...    7.500000
# 50%     11.700000   12.000000   10.700000    9.700000  ...    8.700000
# 75%     13.500000   14.000000   12.200000   11.100000  ...    9.700000
# max     19.000000   21.900000   22.700000   20.700000  ...   21.400000
#
#              2014        2015        2016        2017        2018        2019  \
# count  169.000000  169.000000  169.000000  169.000000  169.000000  169.000000
# mean     8.730769    8.389941    7.676923    8.018935    8.252071    7.585799
# std      2.180842    1.972177    1.800793    1.986082    2.519427    1.566779
# min      3.900000    4.600000    2.900000    3.700000    3.200000    3.000000
# 25%      7.500000    7.300000    6.800000    7.100000    7.100000    6.800000
# 50%      8.900000    8.400000    7.600000    7.800000    7.900000    7.600000
# 75%      9.800000    9.300000    8.600000    8.600000    8.800000    8.500000
# max     20.100000   17.100000   15.300000   17.100000   18.600000   12.900000
#
#              2020        2021        2022
# count  169.000000  169.000000  169.000000
# mean     8.207101    8.569231    7.898225
# std      2.773870    2.322048    2.065749
# min      2.900000    2.500000    2.500000
# 25%      7.000000    7.400000    6.900000
# 50%      7.800000    8.300000    7.700000
# 75%      8.400000    9.400000    8.500000
# max     20.000000   20.700000   20.700000
#
# [8 rows x 23 columns]

# %%
# Which states have the lowest and highest PM2.5 concentration?
low_PM25 = city_pm25['2022'].min()
best_state_PM25 = city_pm25.loc[city_pm25['2022'].idxmin(), 'State']
print(f'{best_state_PM25} is the state with the lowest concentration of PM2.5 with an average value of {low_PM25}')

high_PM25 = city_pm25['2022'].max()
worst_state_PM25 = city_pm25.loc[city_pm25['2022'].idxmax(), 'State']
print(f'{worst_state_PM25} is the state with the highest concentration of PM2.5 with an average value of {high_PM25}')
# Out:
# HI is the state with the lowest concentration of PM2.5 with an average value of 2.5
# CA is the state with the highest concentration of PM2.5 with an average value of 20.7
