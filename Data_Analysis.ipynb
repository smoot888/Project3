# %%
import pandas as pd
import sqlalchemy
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import TextBox
import scipy.stats as stats
from scipy.stats import ttest_ind
import statsmodels.api as sm
from statsmodels.formula.api import ols
from pathlib import Path
import sqlite3
import plotly.graph_objects as go
import plotly.express as px
from ipywidgets import widgets, interactive
import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output

# %%
#Connecting to the historical sqlite server
conn = sqlite3.connect('data/historical.sqlite')

# %%
#Saving the historic table as a dataframe to be explored
historic_df = pd.read_sql_query("SELECT * FROM historical;", conn)

# %%
#Looking at the historic dataframe
historic_df.head()
# Out:
#    Primary Key   CBSA    City State Pollutant       Trend Statistic  \
# 0            1  10420   Akron    OH        O3               4th Max
# 1            2  10420   Akron    OH     PM2.5  Weighted Annual Mean
# 2            3  10420   Akron    OH     PM2.5       98th Percentile
# 3            4  10420   Akron    OH       SO2       99th Percentile
# 4            5  10500  Albany    GA     PM2.5  Weighted Annual Mean
#
#    Number of Sites    1990     1991     1992  ...    2013   2014    2015  \
# 0                2    0.09    0.101    0.087  ...   0.059   0.06   0.065
# 1                3     NaN      NaN      NaN  ...   9.700   9.90  10.400
# 2                3     NaN      NaN      NaN  ...  24.000  22.00  23.000
# 3                1  161.00  183.000  181.000  ...  23.000  21.00  14.000
# 4                1     NaN      NaN      NaN  ...  10.000  10.30   9.000
#
#     2016    2017    2018    2019    2020    2021   2022
# 0   0.06   0.066   0.068   0.062   0.063   0.067   0.07
# 1   8.20   7.900   7.900   8.200   7.900   8.000   7.10
# 2  17.00  18.000  18.000  21.000  21.000  20.000  17.00
# 3   8.00   3.000   6.000   3.000   4.000   5.000   6.00
# 4   8.70   9.400   8.400   9.300   9.100  10.100   8.30
#
# [5 rows x 40 columns]

# %%
#Dropping the years 1990 - 1999 because most of the pollutant data is missing from these years. We will get more accurate data to compare looking at years 2000-2022

drop_col = ['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999']
mean_2000 = historic_df.drop(columns=drop_col)
mean_2000
# Out:
#       Primary Key   CBSA       City State Pollutant       Trend Statistic  \
# 0               1  10420      Akron    OH        O3               4th Max
# 1               2  10420      Akron    OH     PM2.5  Weighted Annual Mean
# 2               3  10420      Akron    OH     PM2.5       98th Percentile
# 3               4  10420      Akron    OH       SO2       99th Percentile
# 4               5  10500     Albany    GA     PM2.5  Weighted Annual Mean
# ...           ...    ...        ...   ...       ...                   ...
# 1421          709  49700  Yuba City    CA       NO2           Annual Mean
# 1422          710  49700  Yuba City    CA       NO2       98th Percentile
# 1423          711  49700  Yuba City    CA        O3               4th Max
# 1424          712  49700  Yuba City    CA     PM2.5  Weighted Annual Mean
# 1425          713  49700  Yuba City    CA     PM2.5       98th Percentile
#
#       Number of Sites     2000     2001    2002  ...    2013    2014    2015  \
# 0                   2    0.085    0.096    0.10  ...   0.059   0.060   0.065
# 1                   3   16.200   16.200   16.00  ...   9.700   9.900  10.400
# 2                   3   37.000   44.000   40.00  ...  24.000  22.000  23.000
# 3                   1  163.000  132.000  145.00  ...  23.000  21.000  14.000
# 4                   1   16.600   14.600   13.80  ...  10.000  10.300   9.000
# ...               ...      ...      ...     ...  ...     ...     ...     ...
# 1421                1   13.000   14.000   15.00  ...  10.000   8.000   7.000
# 1422                1   67.000   64.000   62.00  ...  52.000  44.000  39.000
# 1423                1    0.079    0.081    0.08  ...   0.060   0.069   0.064
# 1424                1   10.600   11.900   13.10  ...   8.200   9.400   9.600
# 1425                1   38.000   54.000   34.00  ...  25.000  25.000  31.000
#
#         2016    2017    2018    2019    2020    2021    2022
# 0      0.060   0.066   0.068   0.062   0.063   0.067   0.070
# 1      8.200   7.900   7.900   8.200   7.900   8.000   7.100
# 2     17.000  18.000  18.000  21.000  21.000  20.000  17.000
# 3      8.000   3.000   6.000   3.000   4.000   5.000   6.000
# 4      8.700   9.400   8.400   9.300   9.100  10.100   8.300
# ...      ...     ...     ...     ...     ...     ...     ...
# 1421   7.000   7.000   7.000   6.000   6.000   5.000   7.000
# 1422  40.000  42.000  41.000  40.000  38.000  34.000  37.000
# 1423   0.063   0.067   0.065   0.061   0.066   0.072   0.058
# 1424   8.100   9.300  10.300   8.400  16.400  14.500  10.700
# 1425  22.000  32.000  37.000  27.000  91.000  45.000  28.000
#
# [1426 rows x 30 columns]

# %%
#store all the years as a list to call easier
years = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']

# %%
#Create a dataframe containing state, city, and year total pollutiion

state_df = (mean_2000.groupby(['State', 'City'], sort=True, as_index=False)[years].sum())
state_df
# Out:
#     State          City     2000     2001     2002     2003     2004     2005  \
# 0      AK     Anchorage   62.400   73.800   71.000   70.600   86.600   67.000
# 1      AK        Juneau   61.200   63.200   52.400   58.800   65.200   86.200
# 2      AL    Birmingham  641.582  379.366  296.370  315.754  325.948  361.168
# 3      AL        Daphne  101.000   65.200   66.800   82.400   78.800   75.400
# 4      AL       Decatur   88.200   88.200   88.200   87.400   82.400   99.400
# ..    ...           ...      ...      ...      ...      ...      ...      ...
# 240    WY      Gillette  146.000  130.000  138.000  132.000  126.000  112.000
# 241    WY       Laramie    0.086    0.102    0.088    0.098    0.096    0.076
# 242    WY      Riverton  183.200  171.200  199.200  168.200  199.200  177.400
# 243    WY  Rock Springs   64.400   65.000   84.000   64.400   64.000   62.400
# 244    WY      Sheridan   94.200  102.000   76.200   72.200   98.000   85.000
#
#         2006     2007  ...     2013     2014     2015     2016     2017  \
# 0     88.400   51.600  ...   61.400   77.000   74.600   64.200   74.200
# 1     83.000   93.200  ...   57.800   71.400   55.200   60.000   55.200
# 2    336.972  328.584  ...  174.130  168.728  226.536  147.340  141.124
# 3     74.400   64.800  ...   50.800   51.800   53.200   42.400   52.800
# 4     84.400  108.800  ...   49.200   60.600   51.600   40.800   47.400
# ..       ...      ...  ...      ...      ...      ...      ...      ...
# 240  176.000  188.000  ...  128.000   94.000  156.000  100.000  190.000
# 241    0.094    0.084  ...    0.138    0.130    0.128    0.128    0.132
# 242  155.400  145.000  ...  151.600  167.400  122.400  117.600  146.800
# 243   73.000   80.400  ...   74.000   58.600   70.600   61.400   91.600
# 244   67.400   72.800  ...   47.400   51.000   65.000   59.800   65.400
#
#        2018     2019     2020     2021     2022
# 0     51.40   89.600   62.600   54.800   60.200
# 1     57.80   63.600   43.600   43.400   56.600
# 2    138.53  132.942  123.922  137.722  126.128
# 3     48.20   45.000   49.800   44.600   44.600
# 4     46.80   43.200   46.200   66.000   59.000
# ..      ...      ...      ...      ...      ...
# 240   78.00   78.000  122.000  168.000  144.000
# 241    0.14    0.130    0.132    0.144    0.134
# 242  142.60  134.000  210.600  197.000  163.600
# 243   90.00   70.000  139.600   94.600   92.400
# 244   56.40   48.000   80.800   71.000   71.000
#
# [245 rows x 25 columns]

# %%
#Making a new dataframe from the above containing the averages for a future line graph
state_avg = state_df.groupby('State').mean().reset_index()
state_avg.head()
# Out:
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_96708/3824548273.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   state_avg = state_df.groupby('State').mean().reset_index()
#   State        2000        2001        2002        2003        2004  \
# 0    AK   61.800000   68.500000   61.700000   64.700000   75.900000
# 1    AL  167.346500  113.962000  102.411750  104.034250  106.581000
# 2    AR   49.619000   46.800000   45.316000   39.007000   40.295000
# 3    AZ  149.439200  136.632400  126.364000  150.560400  100.394000
# 4    CA  215.974857  228.705929  212.931357  183.257571  173.293286
#
#          2005        2006        2007        2008  ...        2013  \
# 0   76.600000   85.700000   72.400000   70.800000  ...   59.600000
# 1  116.882750  105.890000  111.836250   94.232500  ...   61.028000
# 2   53.811000   38.317000   42.887000   37.705000  ...   31.534000
# 3  118.041200  142.678000  122.352000  123.114400  ...  140.234400
# 4  177.746357  181.124857  180.338429  188.112786  ...  159.352571
#
#          2014        2015        2016        2017        2018        2019  \
# 0   74.200000   64.900000   62.100000   64.700000   54.600000   76.600000
# 1   64.254500   72.229250   54.505000   55.000750   54.229750   51.928500
# 2   32.325000   29.823000   28.519000   27.318000   30.428000   28.616000
# 3  143.029600   94.508800  115.625200  125.830400  156.030800   93.785200
# 4  152.122143  142.914143  131.176571  169.186286  225.781286  131.448857
#
#          2020        2021        2022
# 0   53.100000   49.100000   58.400000
# 1   54.744250   57.497750   54.727250
# 2   26.314000   30.427000   29.023000
# 3  119.391200  142.030800  114.628000
# 4  216.321786  166.682786  142.791714
#
# [5 rows x 24 columns]

# %%
state_avg.set_index('State', inplace=True)

# %%
#Transpose the data to build a line graph
state_avg_pose = state_avg.transpose()
state_avg_pose.head()
# Out:
# State    AK         AL      AR        AZ          CA          CO          CT  \
# 2000   61.8  167.34650  49.619  149.4392  215.974857  146.604000  145.371333
# 2001   68.5  113.96200  46.800  136.6324  228.705929  152.770333  153.332000
# 2002   61.7  102.41175  45.316  126.3640  212.931357  144.710000  145.279333
# 2003   64.7  104.03425  39.007  150.5604  183.257571  134.113667  148.986000
# 2004   75.9  106.58100  40.295  100.3940  173.293286  137.968333  129.492000
#
# State     DE          FL         GA  ...          SC      TN        TX  \
# 2000    94.4  192.231333  107.89525  ...  103.702667  9.6855  145.9194
# 2001    94.0  179.510333   99.36375  ...  100.360667  9.1725  135.8856
# 2002   120.2  160.082000   92.31275  ...   86.436000  8.1900  135.4768
# 2003    87.4  146.472333   91.13600  ...   85.753333  4.1640  134.1726
# 2004    87.2  154.388000   98.93525  ...   95.553333  8.1495  129.5066
#
# State          UT       VA         VT       WA         WI        WV       WY
# 2000   126.463333  200.461  75.160000  49.2880  90.743714  254.3888  97.5772
# 2001   161.454000  209.478  68.839333  46.6860  86.380571  259.5468  93.6604
# 2002   147.926000  213.290  79.513333  45.4390  77.209714  272.6328  99.4976
# 2003   130.519333  209.257  77.031333  43.1000  76.721429  220.4684  87.3796
# 2004   172.644667  197.946  74.763333  48.6965  76.563429  238.8552  97.4592
#
# [5 rows x 47 columns]

# %%
state_avg_pose.reset_index(inplace=True)

# %%
#Renaming the column to year
state_avg_pose.rename(columns={'index':'Year'})
# Out:
# State  Year    AK         AL      AR        AZ          CA          CO  \
# 0      2000  61.8  167.34650  49.619  149.4392  215.974857  146.604000
# 1      2001  68.5  113.96200  46.800  136.6324  228.705929  152.770333
# 2      2002  61.7  102.41175  45.316  126.3640  212.931357  144.710000
# 3      2003  64.7  104.03425  39.007  150.5604  183.257571  134.113667
# 4      2004  75.9  106.58100  40.295  100.3940  173.293286  137.968333
# 5      2005  76.6  116.88275  53.811  118.0412  177.746357  122.575000
# 6      2006  85.7  105.89000  38.317  142.6780  181.124857  115.411667
# 7      2007  72.4  111.83625  42.887  122.3520  180.338429  134.974333
# 8      2008  70.8   94.23250  37.705  123.1144  188.112786  128.306000
# 9      2009  76.4   74.17075  33.893  119.7460  154.961000  111.001000
# 10     2010  77.4   85.25500  34.401   97.3132  135.337429  117.671667
# 11     2011  65.5   82.38825  37.142  155.2792  149.185643  112.409000
# 12     2012  71.9   68.41550  34.443  124.4780  140.900429  129.945333
# 13     2013  59.6   61.02800  31.534  140.2344  159.352571  121.408667
# 14     2014  74.2   64.25450  32.325  143.0296  152.122143  122.270333
# 15     2015  64.9   72.22925  29.823   94.5088  142.914143  113.005333
# 16     2016  62.1   54.50500  28.519  115.6252  131.176571  113.269333
# 17     2017  64.7   55.00075  27.318  125.8304  169.186286  107.370333
# 18     2018  54.6   54.22975  30.428  156.0308  225.781286  109.405667
# 19     2019  76.6   51.92850  28.616   93.7852  131.448857  115.266000
# 20     2020  53.1   54.74425  26.314  119.3912  216.321786  146.473667
# 21     2021  49.1   57.49775  30.427  142.0308  166.682786  124.711000
# 22     2022  58.4   54.72725  29.023  114.6280  142.791714   91.438333
#
# State          CT     DE          FL  ...          SC      TN        TX  \
# 0      145.371333   94.4  192.231333  ...  103.702667  9.6855  145.9194
# 1      153.332000   94.0  179.510333  ...  100.360667  9.1725  135.8856
# 2      145.279333  120.2  160.082000  ...   86.436000  8.1900  135.4768
# 3      148.986000   87.4  146.472333  ...   85.753333  4.1640  134.1726
# 4      129.492000   87.2  154.388000  ...   95.553333  8.1495  129.5066
# 5      147.186667   96.4  151.656667  ...  102.360667  9.1625  131.6658
# 6      132.184000   85.8  153.409833  ...   83.693333  8.6620  145.5458
# 7      125.049333   86.2  148.204333  ...   96.152667  9.1695  129.1342
# 8      114.229333   78.6  128.499000  ...   73.421333  7.6535  119.0900
# 9      109.343333   61.0  110.105833  ...   74.062000  6.1345  106.2706
# 10     103.359333   60.6  111.311333  ...   81.808667  6.6530  107.5746
# 11     113.233333   65.2   98.379500  ...   86.813333  6.1485  104.9006
# 12      87.904667   58.4   92.093000  ...   67.126000  6.1525  103.7542
# 13      97.698667   64.2   87.188333  ...   61.786667  5.6280   92.0470
# 14      97.348000   64.4   96.005333  ...   60.055333  5.1320   92.1788
# 15      99.026000   61.4   78.950667  ...   61.652667  4.6340   87.8910
# 16      90.824667   53.2   74.085167  ...   81.662000  4.6365   79.0982
# 17      84.756667   49.4   89.140000  ...   55.790667  4.1285   85.0420
# 18      88.020000   49.0   76.806167  ...   54.253333  4.1335   92.8476
# 19      80.958000   53.2   85.885500  ...   69.784000  3.6270   79.2224
# 20      88.412000   40.8   85.698500  ...   65.380000  3.6160   86.7774
# 21      88.754000   48.8   86.614333  ...   64.855333  3.6265   89.6618
# 22      83.550667   48.8   94.485000  ...   68.988667  3.1255   89.9610
#
# State          UT       VA         VT       WA         WI        WV        WY
# 0      126.463333  200.461  75.160000  49.2880  90.743714  254.3888   97.5772
# 1      161.454000  209.478  68.839333  46.6860  86.380571  259.5468   93.6604
# 2      147.926000  213.290  79.513333  45.4390  77.209714  272.6328   99.4976
# 3      130.519333  209.257  77.031333  43.1000  76.721429  220.4684   87.3796
# 4      172.644667  197.946  74.763333  48.6965  76.563429  238.8552   97.4592
# 5      116.728000  213.658  75.161333  46.9875  96.865429  226.4252   87.3752
# 6      115.521333  201.757  63.222000  44.2470  86.364571  210.0628   94.3788
# 7      172.588000  206.458  65.169333  42.8370  90.088286  231.6664   97.2568
# 8      175.652000  147.654  55.694000  41.7805  85.531143  196.3788   85.2176
# 9      182.647333  130.028  51.485333  45.2835  84.389143  191.1692   91.6196
# 10     145.782667  133.852  47.887333  35.9295  81.533143  118.8572   85.1392
# 11     106.712000  122.145  51.411333  39.5765  71.536000  104.5380   84.7060
# 12      87.911333   97.446  38.422667  38.7845  69.289143   75.6600   94.6684
# 13     195.441333  103.020  31.682667  43.1765  64.790286   72.9324   80.2276
# 14      98.182667  104.223  39.946667  35.0795  69.736286   73.3736   74.2260
# 15      92.248667   94.824  33.819333  38.3350  62.932286   77.2152   82.8256
# 16      98.050667   92.929  23.418000  32.4775  42.309143   58.6144   67.7856
# 17     108.118667   79.321  22.550000  52.3470  38.903143   59.6900   98.7864
# 18     110.720000   77.824  25.018000  51.8505  44.078286   58.7308   73.4280
# 19      74.182000   74.920  25.740000  35.4265  46.298857   58.8904   66.0260
# 20     103.186667   61.108  25.672667  86.2805  40.906571   54.9260  110.6264
# 21     122.654667   68.620  24.349333  52.0910  52.104857   61.8488  106.1488
# 22      97.516667   64.618  22.742667  39.3370  43.246286   55.0492   94.2268
#
# [23 rows x 48 columns]

# %%
#Creating a dash app to display a line chart that shows overall pollution by year with a dropdown for each state

# Create a Dash app
appState = dash.Dash(__name__)


dropdown_options = [{'label': col, 'value': col} for col in state_avg_pose.columns[1:]]

# Define app layout
appState.layout = html.Div([
    dcc.Dropdown(
        id='dropdown',
        options=[{'label': state, 'value': state} for state in state_avg_pose.columns[1:]],
        value='AK'
    ),
    dcc.Graph(id='line-plot1')
])

# Define callback to update the line plot
@appState.callback(
    Output('line-plot1', 'figure'),
    [Input('dropdown', 'value')]
)
def update_line_plot(selected_column):
    fig = px.line(state_avg_pose, x='index', y=selected_column)

    title = f'{selected_column} pollution'

    return fig

# Run the app
if __name__ == '__main__':
    appState.run_server(debug=True, port=8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Using the above table, perform a t-test for each state checking for significant difference at the 0.05 significance level between overall pollution in 2000 and 2022.

for state in state_df['State'].unique():
    data_2000 = state_df.loc[state_df['State'] == state, '2000']
    data_2022 = state_df.loc[state_df['State'] == state, '2022']

    t_statistic, p_value = ttest_ind(data_2000, data_2022)

    print(f'State: {state}')
    print(f't_statistic: {t_statistic}')
    print(f'p_value: {p_value}')
    if p_value < 0.05:
        print('There is a significant difference between pollution in 2000 and 2022')

        if p_value > 0:
            print('There is a significant decrease in overall pollution')

            if t_statistic > 0:
                print('There was a significant decrease in pollution between 2000 and 2022')
            else:
                print('There was a significant increase in pollution between 2000 and 2022')

        else:
            print('There is a significant increase in ovall pollution')

    else:
        print('No significant difference between pollution in 2000 and 2022')

    print('-------------------------------')
    print('-------------------------------')
# Out:
# State: AK
# t_statistic: 1.7919573407620772
# p_value: 0.21501293588266346
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: AL
# t_statistic: 1.509119356832565
# p_value: 0.15350272780958907
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: AR
# t_statistic: 0.35898337317828977
# p_value: 0.7539633195973889
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: AZ
# t_statistic: 0.37094151853907703
# p_value: 0.7203114747322883
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: CA
# t_statistic: 1.6670329313806622
# p_value: 0.10129822141399748
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: CO
# t_statistic: 0.9068059874114897
# p_value: 0.38583897457444283
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: CT
# t_statistic: 1.1024462679867428
# p_value: 0.3321372814411028
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: DE
# t_statistic: nan
# p_value: nan
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: FL
# t_statistic: 1.8634566238385488
# p_value: 0.07580167416626808
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: GA
# t_statistic: 2.0405161039209263
# p_value: 0.06062564299210071
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: HI
# t_statistic: 0.38672184686817074
# p_value: 0.7362305165745376
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: IA
# t_statistic: 0.6465995476798266
# p_value: 0.5418197360593943
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: IL
# t_statistic: 0.6591564859626166
# p_value: 0.5342603601718912
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: IN
# t_statistic: 1.8518774507772702
# p_value: 0.08051825256107223
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: KS
# t_statistic: nan
# p_value: nan
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: KY
# t_statistic: 1.2585077560009938
# p_value: 0.2367962410854988
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: LA
# t_statistic: 1.2037737300113978
# p_value: 0.25188607494431214
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: MA
# t_statistic: 0.5842705320019365
# p_value: 0.6181623331201782
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: MD
# t_statistic: nan
# p_value: nan
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: ME
# t_statistic: 2.7854300726557777
# p_value: 0.049542753364461636
# There is a significant difference between pollution in 2000 and 2022
# There is a significant decrease in overall pollution
# There was a significant decrease in pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MI
# t_statistic: 0.7203982739740523
# p_value: 0.4816728516436035
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: MN
# t_statistic: 3.032739979663868
# p_value: 0.09369492398760829
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: MO
# t_statistic: 0.5708753705723302
# p_value: 0.6256775199318834
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: MT
# t_statistic: 1.03187147995975
# p_value: 0.36043483683243915
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NC
# t_statistic: 1.4805735647291767
# p_value: 0.15430242918558273
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: ND
# t_statistic: 0.5293751799782256
# p_value: 0.6494310255492112
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NE
# t_statistic: nan
# p_value: nan
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NH
# t_statistic: 0.7790398451808136
# p_value: 0.46556251544613825
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NJ
# t_statistic: 1.1713252398688192
# p_value: 0.30648054846483963
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NM
# t_statistic: -0.35001116581060143
# p_value: 0.7597534000968444
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NV
# t_statistic: -0.04240574964002057
# p_value: 0.9700280780750383
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: NY
# t_statistic: 1.210142974676009
# p_value: 0.2462605610101202
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: OH
# t_statistic: 2.2301524662276977
# p_value: 0.03534885283055519
# There is a significant difference between pollution in 2000 and 2022
# There is a significant decrease in overall pollution
# There was a significant decrease in pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OK
# t_statistic: 1.1471937071876557
# p_value: 0.31525381630047306
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: OR
# t_statistic: -0.7431949152475195
# p_value: 0.4854348452899655
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: PA
# t_statistic: 2.0421613379674888
# p_value: 0.051400630452641954
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: PR
# t_statistic: nan
# p_value: nan
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: SC
# t_statistic: 0.4413991078927323
# p_value: 0.6817348941536943
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: TN
# t_statistic: 0.6588118633389106
# p_value: 0.5344669237041608
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: TX
# t_statistic: 0.8191529345696595
# p_value: 0.423412828158356
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: UT
# t_statistic: 0.2910394400444567
# p_value: 0.7854885788013977
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: VA
# t_statistic: 2.967599620066812
# p_value: 0.09726597051933387
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: VT
# t_statistic: 0.6689423986298781
# p_value: 0.540159297482557
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: WA
# t_statistic: 0.27388586312299773
# p_value: 0.7933569759041226
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: WI
# t_statistic: 1.3634477714718864
# p_value: 0.19777414411776875
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: WV
# t_statistic: 2.125053009601314
# p_value: 0.06630163791915927
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# State: WY
# t_statistic: 0.07791734695181364
# p_value: 0.9398073879076851
# No significant difference between pollution in 2000 and 2022
# -------------------------------
# -------------------------------
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_96708/2265845239.py:7: RuntimeWarning:
#
# Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# invalid value encountered in scalar multiply

# %% [markdown]
# For the following we will look at each pollutant seperately.

# %%
#Create a dataframe containing only the pollutant O3
O3 = ['O3']
O3_df = mean_2000[mean_2000['Pollutant'].isin(O3) == True]
state_O3 = (O3_df.groupby(['State', 'City'], sort=True, as_index=False)[years].sum())
state_O3
# Out:
#     State         City   2000   2001   2002   2003   2004   2005   2006  \
# 0      AL   Birmingham  0.182  0.166  0.170  0.154  0.148  0.168  0.172
# 1      AL   Fort Payne  0.068  0.064  0.058  0.060  0.054  0.060  0.076
# 2      AL   Huntsville  0.176  0.160  0.156  0.158  0.154  0.150  0.158
# 3      AL       Mobile  0.178  0.152  0.150  0.160  0.148  0.146  0.170
# 4      AL   Montgomery  0.168  0.154  0.160  0.142  0.144  0.138  0.144
# ..    ...          ...    ...    ...    ...    ...    ...    ...    ...
# 170    WI       Wausau  0.146  0.144  0.146  0.148  0.130  0.150  0.132
# 171    WI   Whitewater  0.152  0.176  0.168  0.162  0.138  0.166  0.144
# 172    WV   Charleston  0.170  0.166  0.174  0.176  0.138  0.158  0.154
# 173    WV  Parkersburg  0.174  0.168  0.190  0.166  0.138  0.168  0.160
# 174    WY      Laramie  0.086  0.102  0.088  0.098  0.096  0.076  0.094
#
#       2007  ...   2013   2014   2015   2016   2017   2018   2019   2020  \
# 0    0.184  ...  0.130  0.128  0.136  0.140  0.124  0.130  0.142  0.122
# 1    0.040  ...  0.124  0.124  0.130  0.128  0.116  0.128  0.124  0.114
# 2    0.164  ...  0.128  0.128  0.126  0.132  0.126  0.130  0.126  0.114
# 3    0.154  ...  0.120  0.136  0.120  0.124  0.130  0.130  0.118  0.108
# 4    0.148  ...  0.122  0.120  0.122  0.116  0.110  0.120  0.118  0.096
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 170  0.144  ...  0.126  0.128  0.126  0.136  0.120  0.130  0.118  0.110
# 171  0.150  ...  0.134  0.146  0.134  0.144  0.130  0.140  0.124  0.148
# 172  0.164  ...  0.134  0.134  0.134  0.138  0.134  0.132  0.130  0.114
# 173  0.168  ...  0.128  0.134  0.142  0.134  0.116  0.122  0.122  0.116
# 174  0.084  ...  0.138  0.130  0.128  0.128  0.132  0.140  0.130  0.132
#
#       2021   2022
# 0    0.122  0.128
# 1    0.116  0.122
# 2    0.122  0.130
# 3    0.114  0.122
# 4    0.108  0.116
# ..     ...    ...
# 170  0.120  0.114
# 171  0.138  0.140
# 172  0.130  0.122
# 173  0.114  0.124
# 174  0.144  0.134
#
# [175 rows x 25 columns]

# %%
O3_avg = state_O3.groupby('State').mean().reset_index()
O3_avg.head()
# Out:
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_96708/1882764809.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   State      2000      2001      2002      2003      2004      2005      2006  \
# 0    AL  0.154400  0.139200  0.138800  0.134800  0.129600  0.132400  0.144000
# 1    AR  0.119000  0.100000  0.116000  0.107000  0.095000  0.111000  0.117000
# 2    AZ  0.149000  0.140500  0.155000  0.150500  0.142500  0.151500  0.147500
# 3    CA  0.156952  0.160286  0.165619  0.162476  0.152952  0.147524  0.156952
# 4    CO  0.141333  0.140667  0.153333  0.160667  0.136667  0.150000  0.156667
#
#        2007      2008  ...      2013      2014      2015      2016      2017  \
# 0  0.138000  0.132000  ...  0.124800  0.127200  0.126800  0.128000  0.121200
# 1  0.087000  0.105000  ...  0.134000  0.125000  0.123000  0.119000  0.118000
# 2  0.140000  0.143000  ...  0.143000  0.137000  0.136000  0.131500  0.138000
# 3  0.146476  0.159905  ...  0.136762  0.143810  0.142667  0.140190  0.143619
# 4  0.148667  0.145333  ...  0.150667  0.140667  0.144000  0.138667  0.140667
#
#        2018     2019      2020      2021      2022
# 0  0.127600  0.12560  0.110800  0.116400  0.123600
# 1  0.128000  0.11600  0.114000  0.127000  0.123000
# 2  0.138500  0.13150  0.139000  0.138500  0.135000
# 3  0.136952  0.13181  0.143333  0.138952  0.131810
# 4  0.144667  0.13200  0.147333  0.155333  0.143333
#
# [5 rows x 24 columns]

# %%
state_O3.set_index('City', inplace=True)

# %%
state_O3.head()
# Out:
#            State   2000   2001   2002   2003   2004   2005   2006   2007  \
# City
# Birmingham    AL  0.182  0.166  0.170  0.154  0.148  0.168  0.172  0.184
# Fort Payne    AL  0.068  0.064  0.058  0.060  0.054  0.060  0.076  0.040
# Huntsville    AL  0.176  0.160  0.156  0.158  0.154  0.150  0.158  0.164
# Mobile        AL  0.178  0.152  0.150  0.160  0.148  0.146  0.170  0.154
# Montgomery    AL  0.168  0.154  0.160  0.142  0.144  0.138  0.144  0.148
#
#              2008  ...   2013   2014   2015   2016   2017   2018   2019  \
# City               ...
# Birmingham  0.154  ...  0.130  0.128  0.136  0.140  0.124  0.130  0.142
# Fort Payne  0.072  ...  0.124  0.124  0.130  0.128  0.116  0.128  0.124
# Huntsville  0.146  ...  0.128  0.128  0.126  0.132  0.126  0.130  0.126
# Mobile      0.152  ...  0.120  0.136  0.120  0.124  0.130  0.130  0.118
# Montgomery  0.136  ...  0.122  0.120  0.122  0.116  0.110  0.120  0.118
#
#              2020   2021   2022
# City
# Birmingham  0.122  0.122  0.128
# Fort Payne  0.114  0.116  0.122
# Huntsville  0.114  0.122  0.130
# Mobile      0.108  0.114  0.122
# Montgomery  0.096  0.108  0.116
#
# [5 rows x 24 columns]

# %%
city_O3 = state_O3.transpose()

# %%
city_O3.reset_index(inplace=True)

# %%
city_O3 = city_O3.drop(index=0)

# %%
city_O3.head()
# Out:
# City index Birmingham Fort Payne Huntsville Mobile Montgomery Arkadelphia  \
# 1     2000      0.182      0.068      0.176  0.178      0.168       0.058
# 2     2001      0.166      0.064       0.16  0.152      0.154       0.042
# 3     2002       0.17      0.058      0.156   0.15       0.16       0.062
# 4     2003      0.154       0.06      0.158   0.16      0.142       0.064
# 5     2004      0.148      0.054      0.154  0.148      0.144       0.044
#
# City Little Rock Flagstaff Phoenix  ... Bellingham Seattle Spokane Madison  \
# 1           0.18     0.142   0.164  ...      0.104   0.112   0.136   0.144
# 2          0.158     0.136   0.158  ...        0.1   0.102   0.142   0.156
# 3           0.17     0.158   0.164  ...      0.106   0.108   0.142   0.162
# 4           0.15     0.146   0.162  ...      0.112    0.13   0.158   0.156
# 5          0.146     0.144   0.148  ...      0.124   0.124   0.138    0.13
#
# City Milwaukee Wausau Whitewater Charleston Parkersburg Laramie
# 1        0.164  0.146      0.152       0.17       0.174   0.086
# 2        0.188  0.144      0.176      0.166       0.168   0.102
# 3        0.192  0.146      0.168      0.174        0.19   0.088
# 4        0.184  0.148      0.162      0.176       0.166   0.098
# 5        0.146   0.13      0.138      0.138       0.138   0.096
#
# [5 rows x 176 columns]

# %%
O3_test = city_O3

# %%
O3_test['index'] = pd.to_numeric(O3_test['index'].str.replace('[^\d.]', '', regex=True), errors='coerce')

# %%
O3_test = O3_test.apply(pd.to_numeric, errors='coerce')
O3_test.head()
# Out:
# City  index  Birmingham  Fort Payne  Huntsville  Mobile  Montgomery  \
# 1      2000       0.182       0.068       0.176   0.178       0.168
# 2      2001       0.166       0.064       0.160   0.152       0.154
# 3      2002       0.170       0.058       0.156   0.150       0.160
# 4      2003       0.154       0.060       0.158   0.160       0.142
# 5      2004       0.148       0.054       0.154   0.148       0.144
#
# City  Arkadelphia  Little Rock  Flagstaff  Phoenix  ...  Bellingham  Seattle  \
# 1           0.058        0.180      0.142    0.164  ...       0.104    0.112
# 2           0.042        0.158      0.136    0.158  ...       0.100    0.102
# 3           0.062        0.170      0.158    0.164  ...       0.106    0.108
# 4           0.064        0.150      0.146    0.162  ...       0.112    0.130
# 5           0.044        0.146      0.144    0.148  ...       0.124    0.124
#
# City  Spokane  Madison  Milwaukee  Wausau  Whitewater  Charleston  \
# 1       0.136    0.144      0.164   0.146       0.152       0.170
# 2       0.142    0.156      0.188   0.144       0.176       0.166
# 3       0.142    0.162      0.192   0.146       0.168       0.174
# 4       0.158    0.156      0.184   0.148       0.162       0.176
# 5       0.138    0.130      0.146   0.130       0.138       0.138
#
# City  Parkersburg  Laramie
# 1           0.174    0.086
# 2           0.168    0.102
# 3           0.190    0.088
# 4           0.166    0.098
# 5           0.138    0.096
#
# [5 rows x 176 columns]

# %%
x = O3_test['index']
y = O3_test['Birmingham']

slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
print(r_value)
# Out:
# -0.8223616462784891

# %%
#Creating a dash app to display a line chart that shows O3 pollution by year with a dropdown for each city

# Create a Dash app
appO3 = dash.Dash(__name__)


dropdown_options = [{'label': col, 'value': col} for col in O3_test.columns[1:]]

# Define app layout
appO3.layout = html.Div([
    dcc.Dropdown(
        id='dropdown-O3',
        options=dropdown_options,
        value='Birmingham'
    ),
    dcc.Graph(id='line-plot2')
])

# Define callback to update the line plot
@appO3.callback(
    Output('line-plot2', 'figure'),
    [Input('dropdown-O3', 'value')]
)
def update_line_plot(selected_column):

    #Perform linear regression
    x = O3_test['index']
    y = O3_test[selected_column]

    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
    regression_line = slope * x + intercept


    fig = px.line(O3_test, x='index', y=selected_column)
    fig.add_trace(go.Scatter(x=x, y=regression_line, mode='lines', name='Linear Regression Line'))
    fig.add_annotation(
        text=f'p-value: {p_value:.3f}, r-value: {r_value:.3f}',
        xref='paper', yref='paper',
        x=1.185, y=0.1,
        showarrow=False
    )

    title = f'{selected_column} O3'

    fig.update_layout(title=title, xaxis_title = 'Year' ,yaxis_title = 'O3 Concentration')

    return fig

# Run the app
if __name__ == '__main__':
    appO3.run_server(debug=True, port=8052)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8052/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Using the above table, perform a t-test for each state checking for significant difference at the 0.05 significance level for O3 pollution betweeen 2000 and 2022.
#If values return "nan" it means there was only one record for that state, which does not allow for a t-test.

for state in state_O3['State'].unique():
    data_2000 = state_O3.loc[state_O3['State'] == state, '2000']
    data_2022 = state_O3.loc[state_O3['State'] == state, '2022']

    t_statistic, p_value = ttest_ind(data_2000, data_2022)

    print(f'State: {state}')
    print(f't_statistic: {t_statistic}')
    print(f'p_value: {p_value}')
    if p_value < 0.05:
        print('There is a significant difference in O3 pollution between 2000 and 2022')
        if t_statistic > 0:
            print('There was a significant decrease in O3 pollution between 2000 and 2022')
        else:
            print('There was a significant increase in O3 pollution between 2000 and 2022')
            
    else:
        print('No significant difference in O3 pollution between 2000 and 2022')


    print('-------------------------------')
    print('-------------------------------')
# Out:
# State: AL
# t_statistic: 1.4088771121384105
# p_value: 0.19653270107293333
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: AR
# t_statistic: -0.06549461226639136
# p_value: 0.9537378997940775
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: AZ
# t_statistic: 1.9051586888313579
# p_value: 0.10541314582633256
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CA
# t_statistic: 3.0086178285435383
# p_value: 0.004524666556723182
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CO
# t_statistic: -0.4242640687119297
# p_value: 0.6931965033474388
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CT
# t_statistic: 4.035856240405547
# p_value: 0.015657535292376644
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: FL
# t_statistic: 9.535714285714288
# p_value: 1.8467937445058014e-08
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: GA
# t_statistic: 11.799999999999988
# p_value: 0.0071053905545293665
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: HI
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: IL
# t_statistic: 4.47693475329673
# p_value: 0.00420614299167138
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: IN
# t_statistic: -0.4266773537513129
# p_value: 0.6786540865877273
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: KS
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: KY
# t_statistic: 8.520563361656322
# p_value: 6.750733351524476e-06
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: LA
# t_statistic: 11.041933833746906
# p_value: 3.2827296874636774e-05
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MA
# t_statistic: 6.516946235415332
# p_value: 0.0227454502400846
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MD
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: ME
# t_statistic: 2.7854300726557777
# p_value: 0.049542753364461636
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MI
# t_statistic: -0.13922650233796371
# p_value: 0.8920351926413862
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MO
# t_statistic: 2.999999999999993
# p_value: 0.0954659662667095
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MT
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NC
# t_statistic: 19.331582286767777
# p_value: 1.7306909922464942e-13
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: ND
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NE
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NH
# t_statistic: 3.7032803990902066
# p_value: 0.020775715825157057
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NJ
# t_statistic: 0.9184392150683277
# p_value: 0.45534503584162267
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NM
# t_statistic: -0.2626128657194451
# p_value: 0.8174258141649446
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NV
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NY
# t_statistic: 1.2498713019631864
# p_value: 0.23517327220618525
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OH
# t_statistic: 1.9520858747774537
# p_value: 0.06507063152438028
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OK
# t_statistic: 10.285912696499048
# p_value: 0.009319867815919496
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OR
# t_statistic: -0.08058229640253751
# p_value: 0.9396448982122095
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: PA
# t_statistic: 0.982594925436189
# p_value: 0.33486258615476217
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: SC
# t_statistic: 5.277388438354882
# p_value: 0.006181077344966293
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: TN
# t_statistic: 9.669875568304565
# p_value: 7.011690271634063e-05
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: TX
# t_statistic: 5.89862447071615
# p_value: 2.244927393151378e-05
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: UT
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: VA
# t_statistic: 19.23018460649823
# p_value: 0.002693244858166468
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: VT
# t_statistic: 13.000000000000083
# p_value: 0.005865153227565606
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WA
# t_statistic: 0.09480909262799583
# p_value: 0.929026025926628
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WI
# t_statistic: 2.3844195510154944
# p_value: 0.05443894395248785
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WV
# t_statistic: 21.913466179498034
# p_value: 0.002075983140016634
# There is a significant difference in O3 pollution between 2000 and 2022
# There was a significant decrease in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WY
# t_statistic: nan
# p_value: nan
# No significant difference in O3 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_96708/1839760605.py:8: RuntimeWarning:
#
# Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# invalid value encountered in scalar multiply

# %%
#Create a dataframe containing only PM2.5 and continue for each pollutant
pm_2 = ['PM2.5']
pm25_df = mean_2000[mean_2000['Pollutant'].isin(pm_2) == True]
state_pm25 = (pm25_df.groupby(['State', 'City', 'Trend Statistic'], sort=True, as_index=False)[years].sum())
state_pm25
# Out:
#     State         City       Trend Statistic  2000  2001  2002  2003  2004  \
# 0      AK    Anchorage       98th Percentile  40.0  50.0  50.0  46.0  60.0
# 1      AK    Anchorage  Weighted Annual Mean  11.6  12.4  11.6  13.2  13.8
# 2      AK       Juneau       98th Percentile  48.0  52.0  40.0  46.0  52.0
# 3      AK       Juneau  Weighted Annual Mean  13.2  11.2  12.4  12.8  13.2
# 4      AL   Birmingham       98th Percentile  94.0  78.0  72.0  72.0  78.0
# ..    ...          ...                   ...   ...   ...   ...   ...   ...
# 333    WV  Parkersburg  Weighted Annual Mean  35.6  34.8  31.6  29.8  29.8
# 334    WY     Riverton       98th Percentile  66.0  66.0  66.0  52.0  80.0
# 335    WY     Riverton  Weighted Annual Mean  19.2  19.2  19.2  16.2  19.2
# 336    WY     Sheridan       98th Percentile  70.0  80.0  56.0  52.0  78.0
# 337    WY     Sheridan  Weighted Annual Mean  24.2  22.0  20.2  20.2  20.0
#
#      2005  2006  ...  2013  2014  2015  2016  2017  2018  2019  2020  2021  \
# 0    44.0  66.0  ...  44.0  58.0  56.0  46.0  56.0  36.0  70.0  46.0  40.0
# 1    13.4  13.8  ...  11.2  14.0  13.0  12.2  11.2  10.0  14.8  10.6  10.4
# 2    70.0  66.0  ...  46.0  56.0  42.0  48.0  44.0  44.0  50.0  34.0  34.0
# 3    16.2  17.0  ...  11.8  15.4  13.2  12.0  11.2  13.8  13.6   9.6   9.4
# 4    86.0  76.0  ...  42.0  44.0  40.0  34.0  40.0  38.0  36.0  38.0  46.0
# ..    ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 333  32.8  29.4  ...  18.8  19.2  18.6  15.8  16.2  15.4  15.4  14.0  15.8
# 334  60.0  46.0  ...  58.0  52.0  40.0  44.0  54.0  44.0  52.0  74.0  58.0
# 335  15.4  15.4  ...  15.6  13.4  12.4  13.6  14.8  14.6  14.0  14.6  17.0
# 336  66.0  48.0  ...  34.0  38.0  50.0  46.0  50.0  42.0  36.0  68.0  58.0
# 337  19.0  19.4  ...  13.4  13.0  15.0  13.8  15.4  14.4  12.0  12.8  13.0
#
#      2022
# 0    46.0
# 1     9.4
# 2    46.0
# 3    10.6
# 4    38.0
# ..    ...
# 333  14.8
# 334  30.0
# 335  11.6
# 336  58.0
# 337  13.0
#
# [338 rows x 26 columns]

# %%
state_pm25 = state_pm25[state_pm25['Trend Statistic'] != '98th Percentile']
state_pm25
# Out:
#     State         City       Trend Statistic  2000  2001  2002  2003  2004  \
# 1      AK    Anchorage  Weighted Annual Mean  11.6  12.4  11.6  13.2  13.8
# 3      AK       Juneau  Weighted Annual Mean  13.2  11.2  12.4  12.8  13.2
# 5      AL   Birmingham  Weighted Annual Mean  40.0  34.6  32.8  31.4  32.0
# 7      AL       Daphne  Weighted Annual Mean  29.0  21.2  20.8  24.4  22.8
# 9      AL      Decatur  Weighted Annual Mean  26.2  26.2  26.2  27.4  24.4
# ..    ...          ...                   ...   ...   ...   ...   ...   ...
# 329    WV     Fairmont  Weighted Annual Mean  32.0  31.8  30.6  30.0  28.2
# 331    WV   Morgantown  Weighted Annual Mean  30.0  29.8  30.4  29.2  27.6
# 333    WV  Parkersburg  Weighted Annual Mean  35.6  34.8  31.6  29.8  29.8
# 335    WY     Riverton  Weighted Annual Mean  19.2  19.2  19.2  16.2  19.2
# 337    WY     Sheridan  Weighted Annual Mean  24.2  22.0  20.2  20.2  20.0
#
#      2005  2006  ...  2013  2014  2015  2016  2017  2018  2019  2020  2021  \
# 1    13.4  13.8  ...  11.2  14.0  13.0  12.2  11.2  10.0  14.8  10.6  10.4
# 3    16.2  17.0  ...  11.8  15.4  13.2  12.0  11.2  13.8  13.6   9.6   9.4
# 5    36.0  34.6  ...  20.6  21.8  20.6  18.4  19.0  18.0  18.4  17.6  19.6
# 7    23.4  22.4  ...  16.8  17.8  17.2  14.4  14.8  14.2  15.0  15.8  14.6
# 9    27.4  26.4  ...  17.2  18.6  17.6  14.8  15.4  14.8  15.2  14.2  18.0
# ..    ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 329  31.8  29.2  ...  18.6  19.0  19.0  17.2  15.4  14.8  15.2  14.8  14.6
# 331  30.0  27.0  ...  17.8  17.2  16.4  14.8  14.6  13.8  14.4  12.4  15.4
# 333  32.8  29.4  ...  18.8  19.2  18.6  15.8  16.2  15.4  15.4  14.0  15.8
# 335  15.4  15.4  ...  15.6  13.4  12.4  13.6  14.8  14.6  14.0  14.6  17.0
# 337  19.0  19.4  ...  13.4  13.0  15.0  13.8  15.4  14.4  12.0  12.8  13.0
#
#      2022
# 1     9.4
# 3    10.6
# 5    18.4
# 7    14.6
# 9    17.0
# ..    ...
# 329  14.2
# 331  14.0
# 333  14.8
# 335  11.6
# 337  13.0
#
# [169 rows x 26 columns]

# %%
city_pm25 = state_pm25.set_index('City')

# %%
city_pm25.head()
# Out:
#            State       Trend Statistic  2000  2001  2002  2003  2004  2005  \
# City
# Anchorage     AK  Weighted Annual Mean  11.6  12.4  11.6  13.2  13.8  13.4
# Juneau        AK  Weighted Annual Mean  13.2  11.2  12.4  12.8  13.2  16.2
# Birmingham    AL  Weighted Annual Mean  40.0  34.6  32.8  31.4  32.0  36.0
# Daphne        AL  Weighted Annual Mean  29.0  21.2  20.8  24.4  22.8  23.4
# Decatur       AL  Weighted Annual Mean  26.2  26.2  26.2  27.4  24.4  27.4
#
#             2006  2007  ...  2013  2014  2015  2016  2017  2018  2019  2020  \
# City                    ...
# Anchorage   13.8  10.4  ...  11.2  14.0  13.0  12.2  11.2  10.0  14.8  10.6
# Juneau      17.0  13.2  ...  11.8  15.4  13.2  12.0  11.2  13.8  13.6   9.6
# Birmingham  34.6  34.4  ...  20.6  21.8  20.6  18.4  19.0  18.0  18.4  17.6
# Daphne      22.4  20.8  ...  16.8  17.8  17.2  14.4  14.8  14.2  15.0  15.8
# Decatur     26.4  28.8  ...  17.2  18.6  17.6  14.8  15.4  14.8  15.2  14.2
#
#             2021  2022
# City
# Anchorage   10.4   9.4
# Juneau       9.4  10.6
# Birmingham  19.6  18.4
# Daphne      14.6  14.6
# Decatur     18.0  17.0
#
# [5 rows x 25 columns]

# %%
city_pm25.drop(columns=['Trend Statistic'], inplace=True)

# %%
#city_pm25.set_index('City', inplace=True)

# %%
city_25 = city_pm25.transpose()

# %%
city_25.reset_index(inplace=True)

# %%
city_25 = city_25.drop(index=0)

# %%
city_25.head()
# Out:
# City index Anchorage Juneau Birmingham Daphne Decatur Fort Payne Gadsden  \
# 1     2000      11.6   13.2       40.0   29.0    26.2       34.4    39.0
# 2     2001      12.4   11.2       34.6   21.2    26.2       29.4    34.4
# 3     2002      11.6   12.4       32.8   20.8    26.2       28.8    29.6
# 4     2003      13.2   12.8       31.4   24.4    27.4       30.0    28.6
# 5     2004      13.8   13.2       32.0   22.8    24.4       28.2    28.6
#
# City Huntsville Little Rock  ... Madison Milwaukee Platteville Charleston  \
# 1          32.6        31.0  ...    25.6      26.2        24.6       36.2
# 2          29.2        29.4  ...    26.6      27.6        23.8       36.2
# 3          27.6        26.4  ...    24.6      25.4        21.8       34.2
# 4          27.6        25.8  ...    23.8      24.6        22.6       32.2
# 5          26.8        24.4  ...    22.6      24.0        21.6       31.8
#
# City Clarksburg Fairmont Morgantown Parkersburg Riverton Sheridan
# 1          29.8     32.0       30.0        35.6     19.2     24.2
# 2          28.8     31.8       29.8        34.8     19.2     22.0
# 3          28.0     30.6       30.4        31.6     19.2     20.2
# 4          26.8     30.0       29.2        29.8     16.2     20.2
# 5          26.6     28.2       27.6        29.8     19.2     20.0
#
# [5 rows x 170 columns]

# %%
city25_test = city_25
city25_test['index'] = pd.to_numeric(city25_test['index'].str.replace('[^\d.]', '', regex=True), errors='coerce')
city25_test = city25_test.apply(pd.to_numeric, errors='coerce')

# %%
x5 = city25_test['index']
y5 = city25_test['Anchorage']

slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
print(r_value)
# Out:
# -0.8223616462784891

# %%
#Creating a dash app to display a line chart that shows PM2.5 pollution by year with a dropdown for each city

# Create a Dash app
appPM25 = dash.Dash(__name__)


dropdown_options = [{'label': col, 'value': col} for col in city25_test.columns[2:]]

# Define app layout
appPM25.layout = html.Div([
    dcc.Dropdown(
        id='dropdown-PM25',
        options=dropdown_options,
        value='Anchorage'
    ),
    dcc.Graph(id='line-plot3')
])

# Define callback to update the line plot
@appPM25.callback(
    Output('line-plot3', 'figure'),
    [Input('dropdown-PM25', 'value')]
)
def update_line_plot(selected_column):

    #Perform linear regression
    x25 = city25_test['index']
    y25 = city25_test[selected_column]

    slope, intercept, r_value, p_value, std_err = stats.linregress(x25, y25)
    regression_line = slope * x25 + intercept

    #Create the line plots and add the linear regression line with r-value and p-value
    fig = px.line(city25_test, x='index', y=selected_column)
    fig.add_trace(go.Scatter(x=x25, y=regression_line, mode='lines', name='Linear Regression Line'))
    fig.add_annotation(
        text=f'p-value: {p_value:.3f}, r-value: {r_value:.3f}',
        xref='paper', yref='paper',
        x=1.185, y=0.1,
        showarrow=False
    )


    title = f'{selected_column} PM2.5'

    fig.update_layout(title = title, xaxis_title = 'Year', yaxis_title = 'PM2.5 Concentration')

    return fig

# Run the app
if __name__ == '__main__':
    appPM25.run_server(debug=True, port=8053)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8053/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Using the above table, perform a t-test for each state checking for significant difference at the 0.05 significance level of PM2.5 pollution between 2000 and 2022.
#If values return "nan" it means there was only one record for that state, which does not allow for a t-test.

for state in state_pm25['State'].unique():
    data_2000 = state_pm25.loc[state_pm25['State'] == state, '2000']
    data_2022 = state_pm25.loc[state_pm25['State'] == state, '2022']

    t_statistic, p_value = ttest_ind(data_2000, data_2022)

    print(f'State: {state}')
    print(f't_statistic: {t_statistic}')
    print(f'p_value: {p_value}')
    if p_value < 0.05:
        print('There is a significant difference in PM2.5 pollution between 2000 and 2022')
        if t_statistic > 0:
            print('There was a significant decrease in PM2.5 pollution between 2000 and 2022')
        else:
            print('There was a significant increase in PM2.5 pollution between 2000 and 2022')
            
    else:
        print('No significant difference in PM2.5 pollution between 2000 and 2022')


    print('-------------------------------')
# Out:
# State: AK
# t_statistic: 2.3999999999999995
# p_value: 0.1384502096587143
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: AL
# t_statistic: 7.601710220633044
# p_value: 1.8364299284931228e-05
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: AR
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: AZ
# t_statistic: 1.1214296958515246
# p_value: 0.32487611072332695
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: CA
# t_statistic: 2.8265393387646105
# p_value: 0.007175150014392773
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: CO
# t_statistic: 7.003859939637153
# p_value: 0.0004222184586947569
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: CT
# t_statistic: 5.394583842040787
# p_value: 0.00571278093531635
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: DE
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: FL
# t_statistic: 6.246975400302782
# p_value: 4.228399554832331e-06
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: GA
# t_statistic: 8.743929933365866
# p_value: 1.4959837659471997e-06
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: HI
# t_statistic: 2.630383796885715
# p_value: 0.11922898789891165
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: IA
# t_statistic: 6.424951361683604
# p_value: 0.000671595352770918
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: IN
# t_statistic: 9.58743729785981
# p_value: 5.63512481499538e-07
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: KS
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: KY
# t_statistic: 13.247641299491775
# p_value: 0.0001876191319635189
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: LA
# t_statistic: 15.06978397998156
# p_value: 3.343745101244018e-08
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: MA
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: MD
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: MI
# t_statistic: 6.388014259386023
# p_value: 3.4633684270091034e-05
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: MN
# t_statistic: 9.4528533069949
# p_value: 0.011006710173425985
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: MO
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: MT
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NC
# t_statistic: 11.292651166934608
# p_value: 9.487606114188256e-08
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: ND
# t_statistic: -0.7913267865219099
# p_value: 0.5116939255093911
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NE
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NH
# t_statistic: 1.819221943661682
# p_value: 0.21049284058324197
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NJ
# t_statistic: 3.8077703507758685
# p_value: 0.06256660109273532
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NM
# t_statistic: 1.0427120034542843
# p_value: 0.4065575739437923
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NV
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: NY
# t_statistic: 5.624945069164025
# p_value: 0.0004956364635581505
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: OH
# t_statistic: 9.44471305420504
# p_value: 6.045534076757854e-08
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: OK
# t_statistic: 3.8011246773376053
# p_value: 0.019085187356128363
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: OR
# t_statistic: -0.08622939374702118
# p_value: 0.935427940695366
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: PA
# t_statistic: 10.379730969247413
# p_value: 5.017522475001141e-09
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: PR
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: SC
# t_statistic: 5.883484054145521
# p_value: 0.02769441467175341
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: TX
# t_statistic: 2.76112224176952
# p_value: 0.02463204243154619
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: UT
# t_statistic: 2.1828206253269973
# p_value: 0.16074567258371752
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: VA
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: VT
# t_statistic: nan
# p_value: nan
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: WA
# t_statistic: 3.1304951684997047
# p_value: 0.08867762313423297
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: WI
# t_statistic: 10.911322268285554
# p_value: 4.41028065622218e-06
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: WV
# t_statistic: 13.42734240159691
# p_value: 9.065544860186981e-07
# There is a significant difference in PM2.5 pollution between 2000 and 2022
# There was a significant decrease in PM2.5 pollution between 2000 and 2022
# -------------------------------
# State: WY
# t_statistic: 3.6207447141253226
# p_value: 0.06853045853493385
# No significant difference in PM2.5 pollution between 2000 and 2022
# -------------------------------
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_96708/1694952570.py:8: RuntimeWarning:
#
# Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# invalid value encountered in scalar multiply

# %%
#Create a dataframe containing only the SO2 pollutant
SO2 = ['SO2']
SO2_df = mean_2000[mean_2000['Pollutant'].isin(SO2) == True]
state_SO2 = (SO2_df.groupby(['State', 'City'], sort=True, as_index=False)[years].sum())
state_SO2.head()
# Out:
#   State           City   2000   2001   2002   2003   2004   2005   2006  \
# 0    AL     Birmingham  298.0  126.0  100.0  106.0  112.0  140.0  140.0
# 1    CA  San Francisco   40.0   42.0   40.0   30.0   40.0   32.0   44.0
# 2    CA    Santa Maria    8.0   16.0   14.0   10.0   22.0   14.0   10.0
# 3    CO         Denver  130.0  146.0  146.0  116.0   80.0   78.0   66.0
# 4    FL   Jacksonville  214.0  198.0  200.0  136.0  160.0  180.0  188.0
#
#     2007  ...  2013  2014  2015  2016  2017  2018  2019  2020  2021  2022
# 0  100.0  ...  44.0  34.0  34.0  22.0  24.0  22.0  20.0  10.0  14.0  12.0
# 1   36.0  ...  18.0  24.0  16.0  18.0  18.0  20.0  20.0  16.0  18.0  14.0
# 2   10.0  ...   6.0   8.0   4.0   4.0   2.0   4.0   6.0   6.0   4.0   4.0
# 3   60.0  ...  68.0  32.0  30.0  28.0  26.0  14.0  12.0  12.0  12.0  10.0
# 4  106.0  ...  66.0  74.0  54.0  50.0  40.0  44.0  48.0  56.0  40.0  40.0
#
# [5 rows x 25 columns]

# %%
#Mainuplating the dataset to make it useful to make line charts from
city_SO2 = state_SO2.set_index('City')

# %%
city_SO2 = city_SO2.transpose()

# %%
city_SO2.reset_index(inplace=True)

# %%
city_SO2.drop(index=0)
# Out:
# City index Birmingham San Francisco Santa Maria Denver Jacksonville Miami  \
# 1     2000      298.0          40.0         8.0  130.0        214.0  12.0
# 2     2001      126.0          42.0        16.0  146.0        198.0  20.0
# 3     2002      100.0          40.0        14.0  146.0        200.0  12.0
# 4     2003      106.0          30.0        10.0  116.0        136.0  10.0
# 5     2004      112.0          40.0        22.0   80.0        160.0   8.0
# 6     2005      140.0          32.0        14.0   78.0        180.0   4.0
# 7     2006      140.0          44.0        10.0   66.0        188.0   2.0
# 8     2007      100.0          36.0        10.0   60.0        106.0   6.0
# 9     2008      138.0          36.0         8.0   60.0         84.0   2.0
# 10    2009       82.0          26.0         6.0   66.0         74.0   6.0
# 11    2010       66.0          22.0         6.0   70.0        170.0   2.0
# 12    2011       62.0          20.0         8.0   64.0        130.0   2.0
# 13    2012       72.0          18.0         6.0   68.0         68.0   2.0
# 14    2013       44.0          18.0         6.0   68.0         66.0   2.0
# 15    2014       34.0          24.0         8.0   32.0         74.0   2.0
# 16    2015       34.0          16.0         4.0   30.0         54.0   2.0
# 17    2016       22.0          18.0         4.0   28.0         50.0   0.0
# 18    2017       24.0          18.0         2.0   26.0         40.0   4.0
# 19    2018       22.0          20.0         4.0   14.0         44.0   8.0
# 20    2019       20.0          20.0         6.0   12.0         48.0  10.0
# 21    2020       10.0          16.0         6.0   12.0         56.0   2.0
# 22    2021       14.0          18.0         4.0   12.0         40.0   4.0
# 23    2022       12.0          14.0         4.0   10.0         40.0   2.0
#
# City Orlando Palatka Pensacola  ...   York Beaumont Corpus Christi Houston  \
# 1       52.0   108.0     280.0  ...  156.0    270.0           66.0   152.0
# 2       58.0   120.0     200.0  ...   96.0    182.0           56.0   128.0
# 3       32.0    86.0     168.0  ...  116.0    158.0           56.0   128.0
# 4       26.0   106.0     152.0  ...  104.0    156.0           78.0   130.0
# 5       24.0    96.0     170.0  ...  216.0    160.0           80.0   124.0
# 6       24.0   120.0     138.0  ...  224.0    158.0           66.0   124.0
# 7       24.0   122.0     158.0  ...  186.0    322.0           44.0   104.0
# 8       20.0    68.0     162.0  ...  214.0    174.0           34.0    90.0
# 9       16.0    78.0     238.0  ...  192.0    144.0           48.0    62.0
# 10      16.0    88.0     148.0  ...  178.0    164.0           24.0    62.0
# 11      14.0    66.0      90.0  ...   54.0    150.0           32.0    64.0
# 12      10.0    64.0      44.0  ...   68.0     88.0           18.0    66.0
# 13      10.0    52.0      28.0  ...   38.0    100.0           10.0    42.0
# 14       6.0    54.0      58.0  ...   46.0     68.0            8.0    38.0
# 15      14.0    50.0      66.0  ...   52.0     72.0            8.0    44.0
# 16       6.0    44.0      18.0  ...   60.0     76.0            6.0    30.0
# 17       4.0    24.0      16.0  ...   36.0     84.0            6.0    22.0
# 18      10.0    40.0      16.0  ...   20.0     74.0            8.0    38.0
# 19       8.0    26.0      10.0  ...   16.0     64.0           10.0    40.0
# 20       6.0    18.0      24.0  ...   16.0     66.0           18.0    20.0
# 21       8.0    16.0       8.0  ...   12.0     58.0            6.0    20.0
# 22       8.0    28.0      10.0  ...   30.0     92.0            6.0    22.0
# 23       8.0    98.0      14.0  ...   14.0     74.0            8.0    22.0
#
# City Richmond Roanoke Rutland Green Bay Morgantown Parkersburg
# 1       150.0    38.0   114.0     174.0      372.0       386.0
# 2       160.0    36.0    86.0     134.0      394.0       326.0
# 3       184.0    38.0   112.0     124.0      564.0       250.0
# 4       168.0    34.0   110.0     116.0      352.0       262.0
# 5       158.0    32.0   110.0     106.0      364.0       342.0
# 6       188.0    30.0   108.0     156.0      280.0       334.0
# 7       156.0    44.0    88.0     136.0      362.0       194.0
# 8       188.0    34.0    94.0     154.0      386.0       256.0
# 9       116.0    24.0    66.0     156.0      260.0       298.0
# 10       94.0    20.0    54.0     134.0      364.0       238.0
# 11       88.0    20.0    42.0     138.0       48.0       168.0
# 12       76.0    18.0    54.0     144.0       44.0       108.0
# 13       42.0    10.0    32.0     144.0       32.0        48.0
# 14       60.0    10.0    20.0     152.0       28.0        50.0
# 15       58.0    12.0    28.0     158.0       30.0        62.0
# 16       58.0    10.0     4.0     138.0       32.0        56.0
# 17       48.0     8.0     4.0      26.0       18.0        36.0
# 18       36.0     6.0     4.0      22.0       22.0        38.0
# 19       36.0     4.0     4.0      24.0       24.0        32.0
# 20       28.0     6.0     6.0      10.0       28.0        44.0
# 21        6.0     6.0     4.0      12.0       20.0        38.0
# 22        6.0     6.0     4.0      10.0       20.0        32.0
# 23        8.0     6.0     4.0      12.0       22.0        38.0
#
# [23 rows x 48 columns]

# %%
#Creating a dash app to display a line chart that shows SO2 pollution by year with a dropdown for each city

# Create a Dash app
appSO2 = dash.Dash(__name__)


dropdown_options = [{'label': col, 'value': col} for col in city_SO2.columns[1:]]

# Define app layout
appSO2.layout = html.Div([
    dcc.Dropdown(
        id='dropdown-SO2',
        options=dropdown_options,
        value='Birmingham'
    ),
    dcc.Graph(id='line-plot4')
])

# Define callback to update the line plot
@appSO2.callback(
    Output('line-plot4', 'figure'),
    [Input('dropdown-SO2', 'value')]
)
def update_line_plot(selected_column):
    fig = px.line(city_SO2, x='index', y=selected_column)

    title = f'{selected_column} SO2'

    fig.update_layout(title = title, xaxis_title = 'Year', yaxis_title = 'SO2 Concentration')

    return fig

# Run the app
if __name__ == '__main__':
    appSO2.run_server(debug=True, port=8057)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8057/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Using the above table, perform a t-test for each state checking for significant difference at the 0.05 significance level between SO2 pollution in 2000 and 2022. 
#If values return "nan" it means there was only one record for that state, which does not allow for a t-test.

for state in state_SO2['State'].unique():
    data_2000 = state_SO2.loc[state_SO2['State'] == state, '2000']
    data_2022 = state_SO2.loc[state_SO2['State'] == state, '2022']

    t_statistic, p_value = ttest_ind(data_2000, data_2022)

    print(f'State: {state}')
    print(f't_statistic: {t_statistic}')
    print(f'p_value: {p_value}')
    if p_value < 0.05:
        print('There is a significant difference in SO2 pollution between 2000 and 2022')
        if t_statistic > 0:
            print('There was a significant decrease in SO2 pollution between 2000 and 2022')
        else:
            print('There was a significant increase in SO2 pollution between 2000 and 2022')
            
    else:
        print('No significant difference in SO2 pollution between 2000 and 2022')


    print('-------------------------------')
    print('-------------------------------')
# Out:
# State: AL
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CA
# t_statistic: 0.8948249794078403
# p_value: 0.4653077456503607
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CO
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: FL
# t_statistic: 2.3408832387529346
# p_value: 0.04127736090068851
# There is a significant difference in SO2 pollution between 2000 and 2022
# There was a significant decrease in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: GA
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: HI
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: IA
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: IL
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: IN
# t_statistic: 10.15333012566818
# p_value: 0.0005298359203691353
# There is a significant difference in SO2 pollution between 2000 and 2022
# There was a significant decrease in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: KY
# t_statistic: 4.314554973040049
# p_value: 0.04974473186050386
# There is a significant difference in SO2 pollution between 2000 and 2022
# There was a significant decrease in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: LA
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MA
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MI
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MO
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MT
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NC
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: ND
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NY
# t_statistic: 3.0084541518836927
# p_value: 0.03961060266577003
# There is a significant difference in SO2 pollution between 2000 and 2022
# There was a significant decrease in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OH
# t_statistic: 2.357249189874626
# p_value: 0.07789635737091061
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OK
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: PA
# t_statistic: 4.892566218435647
# p_value: 0.0012050411278317148
# There is a significant difference in SO2 pollution between 2000 and 2022
# There was a significant decrease in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: TX
# t_statistic: 2.0497571673129946
# p_value: 0.10972054781854519
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: VA
# t_statistic: 1.553323788268816
# p_value: 0.26055795149966565
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: VT
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WI
# t_statistic: nan
# p_value: nan
# No significant difference in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WV
# t_statistic: 32.83115830658755
# p_value: 0.0009264537265869911
# There is a significant difference in SO2 pollution between 2000 and 2022
# There was a significant decrease in SO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_96708/4207590170.py:8: RuntimeWarning:
#
# Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# invalid value encountered in scalar multiply

# %%
#Create a dataframe containing only NO2 pollutant
NO2 = ['NO2']
NO2_df = mean_2000[mean_2000['Pollutant'].isin(NO2) == True]
state_NO2 = (NO2_df.groupby(['State', 'City'], sort=True, as_index=False)[years].sum())
state_NO2.head()
# Out:
#   State         City   2000   2001   2002   2003   2004   2005   2006   2007  \
# 0    AZ      Phoenix   58.0   52.0   58.0   52.0   48.0   48.0   48.0   42.0
# 1    AZ       Tucson  154.0  136.0  144.0  142.0  134.0  124.0  122.0  124.0
# 2    CA  Bakersfield  134.0  144.0  142.0  140.0  130.0  128.0  146.0  132.0
# 3    CA       Fresno  190.0  168.0  172.0  182.0  148.0  154.0  152.0  146.0
# 4    CA  Los Angeles  286.0  266.0  248.0  258.0  224.0  198.0  204.0  206.0
#
#    ...   2013   2014   2015   2016   2017   2018   2019   2020   2021   2022
# 0  ...   36.0   36.0   32.0   32.0   34.0   32.0   28.0   26.0   30.0   28.0
# 1  ...  108.0  106.0   98.0   84.0   90.0   98.0   92.0   90.0   92.0   88.0
# 2  ...  104.0  100.0   86.0   80.0   80.0   82.0   82.0   74.0   74.0   72.0
# 3  ...  132.0  130.0  112.0  118.0  128.0  136.0  126.0  122.0  104.0  114.0
# 4  ...  152.0  152.0  146.0  140.0  136.0  134.0  124.0  128.0  128.0  122.0
#
# [5 rows x 25 columns]

# %%
#Manipulate the data to make it usable for line graphs
city_NO2 = state_NO2.set_index('City')

# %%
city_NO2.drop(columns={'State'}, inplace=True)

# %%
cityNO2 = city_NO2.transpose()

# %%
cityNO2.reset_index(inplace=True)

# %%
cityNO2.head()
# Out:
# City index  Phoenix  Tucson  Bakersfield  Fresno  Los Angeles  Merced  \
# 0     2000     58.0   154.0        134.0   190.0        286.0    24.0
# 1     2001     52.0   136.0        144.0   168.0        266.0    24.0
# 2     2002     58.0   144.0        142.0   172.0        248.0    24.0
# 3     2003     52.0   142.0        140.0   182.0        258.0    24.0
# 4     2004     48.0   134.0        130.0   148.0        224.0    22.0
#
# City  Modesto  Oxnard  Riverside  ...  Scranton   York  Charleston  Nashville  \
# 0        32.0   156.0      234.0  ...     130.0  166.0        22.0       38.0
# 1        34.0   140.0      238.0  ...     146.0  172.0        22.0       36.0
# 2        34.0   128.0      220.0  ...     146.0  160.0        20.0       32.0
# 3        30.0   130.0      216.0  ...     128.0  146.0        20.0       16.0
# 4        28.0   118.0      200.0  ...     116.0  140.0        20.0       32.0
#
# City  Beaumont  Dallas  El Paso  Houston  Roanoke  Rutland
# 0         98.0   144.0     32.0    168.0    120.0     22.0
# 1        116.0   140.0     36.0    178.0    130.0     26.0
# 2        100.0   146.0     36.0    168.0    120.0     26.0
# 3        102.0   136.0     36.0    160.0    120.0     26.0
# 4        104.0   136.0     34.0    156.0    122.0     24.0
#
# [5 rows x 52 columns]

# %%
#Creating a dash app to display a line chart that shows SO2 pollution by year with a dropdown for each city

# Create a Dash app
appNO2 = dash.Dash(__name__)


dropdown_options = [{'label': col, 'value': col} for col in cityNO2.columns[1:]]

# Define app layout
appNO2.layout = html.Div([
    dcc.Dropdown(
        id='dropdown-NO2',
        options=dropdown_options,
        value='Phoenix'
    ),
    dcc.Graph(id='line-plot5')
])

# Define callback to update the line plot
@appNO2.callback(
    Output('line-plot5', 'figure'),
    [Input('dropdown-NO2', 'value')]
)
def update_line_plot(selected_column):
    fig = px.line(cityNO2, x='index', y=selected_column)

    title = f'{selected_column} NO2'

    fig.update_layout(title = title, xaxis_title = 'Year', yaxis_title = 'NO2 Concentration')

    return fig

# Run the app
if __name__ == '__main__':
    appNO2.run_server(debug=True, port=8060)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8060/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Using the above table, perform a t-test for each state checking for significant difference at the 0.05 significance level between NO2 pollution in 2000 and 2022. 
#If values return "nan" it means there was only one record for that state, which does not allow for a t-test.

for state in state_NO2['State'].unique():
    data_2000 = state_NO2.loc[state_NO2['State'] == state, '2000']
    data_2022 = state_NO2.loc[state_NO2['State'] == state, '2022']

    t_statistic, p_value = ttest_ind(data_2000, data_2022)

    print(f'State: {state}')
    print(f't_statistic: {t_statistic}')
    print(f'p_value: {p_value}')
    if p_value < 0.05:
        print('There is a significant difference in NO2 pollution between 2000 and 2022')
        if t_statistic > 0:
            print('There was a significant decrease in NO2 pollution between 2000 and 2022')
        else:
            print('There was a significant increase in NO2 pollution between 2000 and 2022')
            
    else:
        print('No significant difference in NO2 pollution between 2000 and 2022')


    print('-------------------------------')
    print('-------------------------------')
# Out:
# State: AZ
# t_statistic: 0.847998304005088
# p_value: 0.48574052277341995
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CA
# t_statistic: 2.8663865148272745
# p_value: 0.00779617713821866
# There is a significant difference in NO2 pollution between 2000 and 2022
# There was a significant decrease in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CO
# t_statistic: 0.48586579810734964
# p_value: 0.6750817833556706
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CT
# t_statistic: nan
# p_value: nan
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: FL
# t_statistic: 1.1663763400809437
# p_value: 0.28772140440979
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: GA
# t_statistic: nan
# p_value: nan
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: KY
# t_statistic: 2.2087051361325662
# p_value: 0.15783980636192108
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: LA
# t_statistic: 2.8749445424997293
# p_value: 0.10268791043277536
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MA
# t_statistic: nan
# p_value: nan
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MD
# t_statistic: nan
# p_value: nan
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MO
# t_statistic: nan
# p_value: nan
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NC
# t_statistic: nan
# p_value: nan
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: ND
# t_statistic: nan
# p_value: nan
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NM
# t_statistic: nan
# p_value: nan
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NY
# t_statistic: 0.5819660277171396
# p_value: 0.6194499189815643
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: PA
# t_statistic: 5.204526006846272
# p_value: 0.0003986806817010471
# There is a significant difference in NO2 pollution between 2000 and 2022
# There was a significant decrease in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: SC
# t_statistic: nan
# p_value: nan
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: TN
# t_statistic: nan
# p_value: nan
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: TX
# t_statistic: 0.6647196737041883
# p_value: 0.5309329078053132
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: VA
# t_statistic: nan
# p_value: nan
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: VT
# t_statistic: nan
# p_value: nan
# No significant difference in NO2 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_96708/1630770372.py:8: RuntimeWarning:
#
# Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# invalid value encountered in scalar multiply

# %%
CO = ['CO']
CO_df = mean_2000[mean_2000['Pollutant'].isin(CO) == True]
state_CO = (CO_df.groupby(['State', 'City'], sort=True, as_index=False)[years].sum())
state_CO.head()
# Out:
#   State        City  2000  2001  2002  2003  2004  2005  2006  2007  ...  \
# 0    AK   Anchorage  10.8  11.4   9.4  11.4  12.8   9.6   8.6   7.2  ...
# 1    AL  Birmingham   7.4  12.6   7.4   6.2   7.8   5.0   6.2   4.0  ...
# 2    AZ     Phoenix  10.4   9.0   8.8   7.6   6.8   7.2   6.6   6.0  ...
# 3    AZ      Tucson   9.4   5.8   5.0   5.2   4.0   4.2   3.6   3.8  ...
# 4    CA      Fresno   6.6   5.6   5.0   3.6   3.4   3.6   4.2   3.4  ...
#
#    2013  2014  2015  2016  2017  2018  2019  2020  2021  2022
# 0   6.2   5.0   5.6   6.0   7.0   5.4   4.8   6.0   4.4   4.8
# 1   3.4   4.8   3.8   2.8   2.0   2.4   2.4   2.2   2.0   1.6
# 2   4.0   4.2   3.8   3.8   4.4   4.0   3.4   3.8   3.8   3.4
# 3   2.2   2.0   2.0   1.8   2.0   1.6   1.2   1.6   1.4   1.4
# 4   2.8   2.2   2.0   2.6   2.4   2.6   2.0   4.4   2.2   2.0
#
# [5 rows x 25 columns]

# %%
#Dataframe manipulation for later graph making
city_CO = state_CO.set_index('City')

# %%
city_COpose = city_CO.transpose()

# %%
city_COpose.reset_index(inplace=True)

# %%
cityCO = city_COpose.drop(index=0)

# %%
cityCO.head()
# Out:
# City index Anchorage Birmingham Phoenix Tucson Fresno Los Angeles Riverside  \
# 1     2000      10.8        7.4    10.4    9.4    6.6        10.6       5.2
# 2     2001      11.4       12.6     9.0    5.8    5.6         7.8       4.4
# 3     2002       9.4        7.4     8.8    5.0    5.0         7.0       4.2
# 4     2003      11.4        6.2     7.6    5.2    3.6         6.8       4.8
# 5     2004      12.8        7.8     6.8    4.0    3.4         5.8       3.6
#
# City Sacramento San Francisco  ... Albuquerque  Reno Buffalo New York  \
# 1           9.2           5.4  ...         6.6  10.4     4.0      8.6
# 2          10.0           5.6  ...         5.8   9.2     3.8      7.8
# 3           7.0           4.4  ...         5.6   8.8     3.6      7.2
# 4           7.6           4.2  ...         4.2   7.6     4.8      6.2
# 5           5.6           3.6  ...         4.4   7.8     2.8      6.6
#
# City Cleveland Portland Johnstown Scranton Houston Rutland
# 1         15.8      7.6       4.0      4.2     5.2     5.0
# 2          5.6      6.4       4.2      3.6     4.6     4.4
# 3          4.0      6.0       5.2      3.2     5.6     4.6
# 4          5.4      6.2       4.4      3.0     8.4     3.8
# 5         10.8      7.4       4.2      3.6     3.6     3.6
#
# [5 rows x 30 columns]

# %%
#Creating a dash app to display a line chart that shows CO pollution by year with a dropdown for each city

# Create a Dash app
appCO = dash.Dash(__name__)


dropdown_options = [{'label': col, 'value': col} for col in cityCO.columns[1:]]

# Define app layout
appCO.layout = html.Div([
    dcc.Dropdown(
        id='dropdown-CO',
        options=dropdown_options,
        value='Anchorage'
    ),
    dcc.Graph(id='line-plot6')
])

# Define callback to update the line plot
@appCO.callback(
    Output('line-plot6', 'figure'),
    [Input('dropdown-CO', 'value')]
)
def update_line_plot(selected_column):
    fig = px.line(cityCO, x='index', y=selected_column)

    title = f'{selected_column} CO-pollutant'

    fig.update_layout(title = title, xaxis_title = 'Year', yaxis_title = 'CO Concentration')

    return fig

# Run the app
if __name__ == '__main__':
    appCO.run_server(debug=True, port=8062)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8062/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Using the above table, perform a t-test for each state checking for significant difference at the 0.05 significance level between CO pollution in 1990 and 2022. 
#If values return "nan" it means there was only one record for that state, which does not allow for a t-test.

for state in state_CO['State'].unique():
    data_2000 = state_CO.loc[state_CO['State'] == state, '2000']
    data_2022 = state_CO.loc[state_CO['State'] == state, '2022']

    t_statistic, p_value = ttest_ind(data_2000, data_2022)

    print(f'State: {state}')
    print(f't_statistic: {t_statistic}')
    print(f'p_value: {p_value}')
    if p_value < 0.05:
        print('There is a significant difference in CO pollution between 2000 and 2022')
        if t_statistic > 0:
            print('There was a significant decrease in CO pollution between 2000 and 2022')
        else:
            print('There was a significant increase in CO pollution between 2000 and 2022')
            
    else:
        print('No significant difference in CO pollution between 2000 and 2022')


    print('-------------------------------')
    print('-------------------------------')
# Out:
# State: AK
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: AL
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: AZ
# t_statistic: 6.7082039324993685
# p_value: 0.02150789041983671
# There is a significant difference in CO pollution between 2000 and 2022
# There was a significant decrease in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CA
# t_statistic: 4.2024635912800745
# p_value: 0.0012265180738523498
# There is a significant difference in CO pollution between 2000 and 2022
# There was a significant decrease in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CO
# t_statistic: 10.999999999999998
# p_value: 0.008163401865824484
# There is a significant difference in CO pollution between 2000 and 2022
# There was a significant decrease in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: FL
# t_statistic: 4.365641250653992
# p_value: 0.04867043935295808
# There is a significant difference in CO pollution between 2000 and 2022
# There was a significant decrease in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: HI
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: LA
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MI
# t_statistic: 5.091168824543145
# p_value: 0.036482090370059346
# There is a significant difference in CO pollution between 2000 and 2022
# There was a significant decrease in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NM
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NV
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NY
# t_statistic: 1.4904826270501987
# p_value: 0.27457662909484803
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OH
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OR
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: PA
# t_statistic: 9.391485505499112
# p_value: 0.011148620369176666
# There is a significant difference in CO pollution between 2000 and 2022
# There was a significant decrease in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: TX
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: VT
# t_statistic: nan
# p_value: nan
# No significant difference in CO pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_96708/2221884077.py:8: RuntimeWarning:
#
# Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# invalid value encountered in scalar multiply

# %%
#Create a PM10 dataframe
pm10 = ['PM10']
pm10_df = mean_2000[mean_2000['Pollutant'].isin(pm10) == True]
state_PM10 = (pm10_df.groupby(['State', 'City'], sort=True, as_index=False)[years].sum())
state_PM10.head()
# Out:
#   State        City   2000   2001   2002   2003   2004   2005   2006   2007  \
# 0    AL  Birmingham  202.0  128.0   84.0  100.0   96.0   94.0   80.0  100.0
# 1    AL  Huntsville  113.4   79.4   81.4   86.0   81.4   86.6   78.0  100.0
# 2    AZ     Phoenix  214.0  126.4  160.4  252.4   96.8  152.0  155.6  158.4
# 3    AZ      Tucson  100.0  170.0   60.0   94.0   48.0   62.0  140.0   96.0
# 4    CA      Fresno  223.0  241.0  173.0  163.0  132.0  178.0  197.0  167.0
#
#    ...   2013   2014   2015   2016   2017   2018   2019   2020   2021   2022
# 0  ...   64.0   64.0  128.0   70.0   56.0   58.0   56.0   56.0   56.0   56.0
# 1  ...   52.0   58.6   85.4   78.0   45.4   61.4   57.4   59.4   54.0   66.6
# 2  ...  315.6  275.6  124.4  234.0  229.2  426.8   96.0  170.0  291.6  147.6
# 3  ...   68.0  114.0   46.0   58.0   84.0   62.0  112.0  122.0  120.0  136.0
# 4  ...  170.0  164.0  160.0  150.0  190.0  220.0  194.0  283.0  268.0  268.0
#
# [5 rows x 25 columns]

# %%
city_PM10 = state_PM10.set_index('City')

# %%
city_PM10pose = city_PM10.transpose()

# %%
city_PM10pose.reset_index(inplace=True)

# %%
cityPM10 = city_PM10pose.drop(index=0)

# %%
cityPM10.head()
# Out:
# City index Birmingham Huntsville Phoenix Tucson Fresno Los Angeles Redding  \
# 1     2000      202.0      113.4   214.0  100.0  223.0       172.0    76.0
# 2     2001      128.0       79.4   126.4  170.0  241.0       174.0    88.0
# 3     2002       84.0       81.4   160.4   60.0  173.0       140.0   100.0
# 4     2003      100.0       86.0   252.4   94.0  163.0       172.0    62.0
# 5     2004       96.0       81.4    96.8   48.0  132.0       142.0    80.0
#
# City Riverside Sacramento  ... Cleveland Portsmouth Eugene Pittsburgh  \
# 1        187.2      132.0  ...     126.0      118.0  138.0      122.0
# 2        203.6      154.0  ...     133.0      104.0  150.0      143.6
# 3        170.4      124.0  ...     117.6       78.0  158.0      127.0
# 4        215.0      104.0  ...     121.0       70.0  120.0      132.6
# 5        157.6       94.0  ...     111.6       62.0  100.0      133.6
#
# City Charleston Houston  Provo Gillette Riverton Rock Springs
# 1         104.0   136.0  178.0    146.0     98.0         64.4
# 2         126.0   114.6  202.0    130.0     86.0         65.0
# 3          78.0   135.4  210.0    138.0    114.0         84.0
# 4          86.0   132.6  236.0    132.0    100.0         64.4
# 5          90.0   134.0  222.0    126.0    100.0         64.0
#
# [5 rows x 37 columns]

# %%
#Creating a dash app to display a line chart that shows PM10 pollution by year with a dropdown for each city

# Create a Dash app
appPM10 = dash.Dash(__name__)


dropdown_options = [{'label': col, 'value': col} for col in cityPM10.columns[1:]]

# Define app layout
appPM10.layout = html.Div([
    dcc.Dropdown(
        id='dropdown-PM10',
        options=dropdown_options,
        value='Birmingham'
    ),
    dcc.Graph(id='line-plot7')
])

# Define callback to update the line plot
@appPM10.callback(
    Output('line-plot7', 'figure'),
    [Input('dropdown-PM10', 'value')]
)
def update_line_plot(selected_column):
    fig = px.line(cityPM10, x='index', y=selected_column)

    title = f'{selected_column} PM10'

    fig.update_layout(title = title, xaxis_title = 'Year', yaxis_title = 'PM10 Concentration')

    return fig

# Run the app
if __name__ == '__main__':
    appPM10.run_server(debug=True, port=8064)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8064/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Using the above table, perform a t-test for each state checking for significant difference at the 0.05 significance level of PM10 pollution in 1990 and 2022. 
#If values return "nan" it means there was only one record for that state, which does not allow for a t-test.

for state in state_PM10['State'].unique():
    data_2000 = state_PM10.loc[state_PM10['State'] == state, '2000']
    data_2022 = state_PM10.loc[state_PM10['State'] == state, '2022']

    t_statistic, p_value = ttest_ind(data_2000, data_2022)

    print(f'State: {state}')
    print(f't_statistic: {t_statistic}')
    print(f'p_value: {p_value}')
    if p_value < 0.05:
        print('There is a significant difference in PM10 pollution between 2000 and 2022')
        if t_statistic > 0:
            print('There was a significant decrease in PM10 pollution between 2000 and 2022')
        else:
            print('There was a significant increase in PM10 pollution between 2000 and 2022')
            
    else:
        print('No significant difference in PM10 pollution between 2000 and 2022')


    print('-------------------------------')
    print('-------------------------------')
# Out:
# State: AL
# t_statistic: 2.160663899492874
# p_value: 0.16329153226024773
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: AZ
# t_statistic: 0.26529676809462893
# p_value: 0.8156230279812167
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CA
# t_statistic: 0.3308922656626504
# p_value: 0.7450196635641749
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: CO
# t_statistic: 1.2535422782033492
# p_value: 0.27827697859581185
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: FL
# t_statistic: 0.17755520605710876
# p_value: 0.8754274845413441
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: HI
# t_statistic: nan
# p_value: nan
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: IN
# t_statistic: 0.13349824784699543
# p_value: 0.9060202765485043
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: MI
# t_statistic: 0.03038757206473114
# p_value: 0.9785177003701762
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NM
# t_statistic: -1.4948060066480866
# p_value: 0.27358201803738913
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: NY
# t_statistic: nan
# p_value: nan
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OH
# t_statistic: 4.640353827295477
# p_value: 0.04343712161294212
# There is a significant difference in PM10 pollution between 2000 and 2022
# There was a significant decrease in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: OR
# t_statistic: nan
# p_value: nan
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: PA
# t_statistic: nan
# p_value: nan
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: SC
# t_statistic: nan
# p_value: nan
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: TX
# t_statistic: nan
# p_value: nan
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: UT
# t_statistic: nan
# p_value: nan
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# State: WY
# t_statistic: -0.5951908597426242
# p_value: 0.5837537494244243
# No significant difference in PM10 pollution between 2000 and 2022
# -------------------------------
# -------------------------------
# /var/folders/yd/nx3j_v1j3hj2pbltnq5y9bb40000gn/T/ipykernel_96708/1891266775.py:8: RuntimeWarning:
#
# Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /Users/jesserinskeys/anaconda3/envs/dev/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning:
#
# invalid value encountered in scalar multiply

# %%
#create a dataframe summing the total pollutants in each city by year
city_total_df = (mean_2000.groupby('City', sort=True, as_index=False)[years].sum())

# %%
#Convert list of cities to be used in a dropdown menu for future plots
city_list = city_total_df['City'].tolist()

# %%
#Set index to prepare for dataframe inversion
city_total_df.set_index('City', inplace=True)

# %%
city_total_df.head()
# Out:
#                 2000     2001     2002     2003     2004     2005     2006  \
# City
# Akron        432.570  384.592  402.200  430.380  441.758  397.582  363.748
# Albany       194.140  187.978  179.982  172.762  186.350  196.564  180.540
# Albuquerque  273.944  280.742  332.348  334.152  252.142  308.146  267.342
# Altoona      124.160  136.166  102.178  124.166  122.146  144.154   96.142
# Americus       0.184    0.164    0.140    0.144    0.140    0.142    0.154
#
#                 2007     2008     2009  ...     2013     2014     2015  \
# City                                    ...
# Akron        182.374  159.950  137.534  ...  113.518  105.920   94.930
# Albany       198.356  160.756  150.332  ...  126.326  119.122  115.724
# Albuquerque  280.738  262.328  229.326  ...  343.334  371.324  254.132
# Altoona      112.142  110.150  102.130  ...   58.130   60.120   62.138
# Americus       0.152    0.136    0.120  ...    0.120    0.118    0.114
#
#                 2016     2017     2018     2019     2020     2021     2022
# City
# Akron         66.520   57.932   63.936   64.524   65.926   66.134   60.340
# Albany       106.136  112.722  113.932  108.710  123.908  131.322   98.118
# Albuquerque  283.330  245.338  272.348  248.134  282.542  321.142  348.742
# Altoona       26.124   14.126   16.128   16.128    8.126    8.122   12.124
# Americus       0.130    0.116    0.124    0.124    0.108    0.118    0.118
#
# [5 rows x 23 columns]

# %%
#Transposing the dataframe
cities_df = city_total_df.transpose()
cities_df.head()
# Out:
# City    Akron   Albany  Albuquerque  Altoona  Americus  Anchorage  Ann Arbor  \
# 2000  432.570  194.140      273.944  124.160     0.184       62.4     88.670
# 2001  384.592  187.978      280.742  136.166     0.164       73.8    108.862
# 2002  402.200  179.982      332.348  102.178     0.140       71.0     91.860
# 2003  430.380  172.762      334.152  124.166     0.144       70.6    107.268
# 2004  441.758  186.350      252.142  122.146     0.140       86.6     89.448
#
# City  Appleton  Arkadelphia  Asheville  ...  Washington Court House  \
# 2000      87.0        0.058     98.980  ...                   0.048
# 2001      88.2        0.042     89.152  ...                   0.044
# 2002      79.6        0.062     89.780  ...                   0.040
# 2003      72.8        0.064     87.340  ...                   0.040
# 2004      77.4        0.044     78.746  ...                   0.048
#
# City  Watertown  Wausau  Whitewater  Wichita  Wilmington  Winston  Yakima  \
# 2000      0.144   0.146       0.152   72.560       0.160  392.978    97.0
# 2001      0.204   0.144       0.176   67.968       0.156  402.388    97.0
# 2002      0.200   0.146       0.168   72.758       0.160  442.186    90.4
# 2003      0.178   0.148       0.162   69.360       0.152  383.162    90.4
# 2004      0.142   0.130       0.138   68.736       0.140  406.156   109.8
#
# City     York  Yuba City
# 2000  437.580    257.358
# 2001  383.574    287.962
# 2002  417.802    248.360
# 2003  378.962    229.152
# 2004  460.954    224.146
#
# [5 rows x 236 columns]

# %%
#reset the index
cities_df.reset_index(inplace=True)

# %%
cities_df.head()
# Out:
# City index    Akron   Albany  Albuquerque  Altoona  Americus  Anchorage  \
# 0     2000  432.570  194.140      273.944  124.160     0.184       62.4
# 1     2001  384.592  187.978      280.742  136.166     0.164       73.8
# 2     2002  402.200  179.982      332.348  102.178     0.140       71.0
# 3     2003  430.380  172.762      334.152  124.166     0.144       70.6
# 4     2004  441.758  186.350      252.142  122.146     0.140       86.6
#
# City  Ann Arbor  Appleton  Arkadelphia  ...  Washington Court House  \
# 0        88.670      87.0        0.058  ...                   0.048
# 1       108.862      88.2        0.042  ...                   0.044
# 2        91.860      79.6        0.062  ...                   0.040
# 3       107.268      72.8        0.064  ...                   0.040
# 4        89.448      77.4        0.044  ...                   0.048
#
# City  Watertown  Wausau  Whitewater  Wichita  Wilmington  Winston  Yakima  \
# 0         0.144   0.146       0.152   72.560       0.160  392.978    97.0
# 1         0.204   0.144       0.176   67.968       0.156  402.388    97.0
# 2         0.200   0.146       0.168   72.758       0.160  442.186    90.4
# 3         0.178   0.148       0.162   69.360       0.152  383.162    90.4
# 4         0.142   0.130       0.138   68.736       0.140  406.156   109.8
#
# City     York  Yuba City
# 0     437.580    257.358
# 1     383.574    287.962
# 2     417.802    248.360
# 3     378.962    229.152
# 4     460.954    224.146
#
# [5 rows x 237 columns]

# %%
##Creating a dash app to display a line chart that shows overall pollution by year with a dropdown for each state

# Create a Dash app
app = dash.Dash(__name__)


dropdown_options = [{'label': col, 'value': col} for col in cities_df.columns[1:]]

# Define app layout
app.layout = html.Div([
    dcc.Dropdown(
        id='dropdown-column',
        options=dropdown_options,
        value='Akron'
    ),
    dcc.Graph(id='line-plot')
])

# Define callback to update the line plot
@app.callback(
    Output('line-plot', 'figure'),
    [Input('dropdown-column', 'value')]
)
def update_line_plot(selected_column):
    fig = px.line(cities_df, x='index', y=selected_column)

    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True, port = 8050)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# The following will include some statistics found from these above data starting with the state level.

# %%
state_avg.reset_index(inplace=True)

# %%
#What are the best and worst states for pollution?
lowest_pollutant = state_avg['2022'].min()
best_state = state_avg.loc[state_avg['2022'].idxmin(), 'State']
print(f'{best_state} is the state with the lowest overall pollution concentration with a pollutant density value of {lowest_pollutant}.')

most_pollutant = state_avg['2022'].max()
worst_state = state_avg.loc[state_avg['2022'].idxmax(), 'State']
print(f'{worst_state} is the state with the highest overall pollution concentration with a pollutant density value of {most_pollutant}.')
# Out:
# ME is the state with the lowest overall pollution concentration with a pollutant density value of 0.11533333333333333.
# OR is the state with the highest overall pollution concentration with a pollutant density value of 291.0415.

# %%
#Which states improved and deproved over time the most in pollution concentration?

state_avg['Change_Over_Time'] = state_avg['2022'] - state_avg['2000']

best_change = state_avg['Change_Over_Time'].min()
best_change_state = state_avg.loc[state_avg['Change_Over_Time'].idxmin(), 'State']
print(f'{best_change_state} is the state with the best overall pollution change over time with a pollutant density change of {best_change}.')


worst_change = state_avg['Change_Over_Time'].max()
worst_change_state = state_avg.loc[state_avg['Change_Over_Time'].idxmax(), 'State']
print(f'{worst_change_state} is the state with the worst overall pollution change over time with a pollutant density change of {worst_change}.')
# Out:
# WV is the state with the best overall pollution change over time with a pollutant density change of -199.33960000000002.
# OR is the state with the worst overall pollution change over time with a pollutant density change of 183.70049999999998.

# %% [markdown]
# The following will take a look at the same statistics at the city level.

# %%
city_total_df.reset_index(inplace=True)

# %%
#What are the best and worst cities for pollution?
low_pollutant = city_total_df['2022'].min()
best_city = city_total_df.loc[city_total_df['2022'].idxmin(), 'City']
print(f'{best_city} is the city with the lowest overall pollution concentration with a value of {low_pollutant}.')

high_pollutant = city_total_df['2022'].max()
worst_city = city_total_df.loc[city_total_df['2022'].idxmax(), 'City']
print(f'{worst_city} is the city with the highest pollution concentration with a value of {high_pollutant}.')
# Out:
# Bellingham is the city with the lowest overall pollution concentration with a value of 0.096.
# Eugene is the city with the highest pollution concentration with a value of 1013.516.

# %%
#Which cities improved and deproved over time the most in pollution concentration?

city_total_df['Change_Over_Time'] = city_total_df['2022'] - city_total_df['2000']

best_change_c = city_total_df['Change_Over_Time'].min()
best_change_city = city_total_df.loc[city_total_df['Change_Over_Time'].idxmin(), 'City']
print(f'{best_change_city} is the city with the best overall pollution change over time with a pollutant density change of {best_change_c}.')


worst_change_c = city_total_df['Change_Over_Time'].max()
worst_change_city = city_total_df.loc[city_total_df['Change_Over_Time'].idxmax(), 'City']
print(f'{worst_change_city} is the city with the worst overall pollution change over time with a pollutant density change of {worst_change_c}.')
# Out:
# Birmingham is the city with the best overall pollution change over time with a pollutant density change of -515.454.
# Eugene is the city with the worst overall pollution change over time with a pollutant density change of 760.804.

# %% [markdown]
# Now we will take a look at some statistics at the individual pollutant level.

# %%
#Summary statistics by each year for O3 concentration by state.
O3_avg.describe()
# Out:
#             2000       2001       2002       2003       2004       2005  \
# count  42.000000  42.000000  42.000000  42.000000  42.000000  42.000000
# mean    0.147543   0.149701   0.157200   0.147218   0.135170   0.144417
# std     0.025112   0.027015   0.029795   0.021356   0.018429   0.024093
# min     0.086000   0.084000   0.086000   0.076000   0.092000   0.076000
# 25%     0.134333   0.140232   0.145750   0.141625   0.128857   0.133800
# 50%     0.150250   0.157750   0.159667   0.150583   0.138000   0.148000
# 75%     0.167000   0.165250   0.175619   0.162357   0.145900   0.159500
# max     0.190000   0.198667   0.212667   0.186000   0.164000   0.186667
#
#             2006       2007       2008       2009  ...       2013       2014  \
# count  42.000000  42.000000  42.000000  42.000000  ...  42.000000  42.000000
# mean    0.142379   0.141496   0.134195   0.126487  ...   0.129656   0.128872
# std     0.021282   0.025000   0.019391   0.014451  ...   0.012497   0.009754
# min     0.080000   0.066000   0.082000   0.093000  ...   0.094000   0.104000
# 25%     0.133250   0.130821   0.126708   0.122464  ...   0.124050   0.123429
# 50%     0.143500   0.148762   0.136667   0.128000  ...   0.131000   0.128833
# 75%     0.157000   0.156500   0.146583   0.135125  ...   0.136405   0.135875
# max     0.184000   0.182667   0.168000   0.149500  ...   0.165333   0.148000
#
#             2015       2016       2017       2018       2019       2020  \
# count  42.000000  42.000000  42.000000  42.000000  42.000000  42.000000
# mean    0.131245   0.130421   0.130580   0.133673   0.124486   0.122787
# std     0.010853   0.013433   0.011361   0.011780   0.010679   0.014742
# min     0.096000   0.094000   0.092000   0.092000   0.102000   0.088000
# 25%     0.126200   0.127250   0.125000   0.127450   0.118167   0.113083
# 50%     0.130000   0.130833   0.129167   0.134250   0.125300   0.119429
# 75%     0.136750   0.138000   0.135889   0.139750   0.129833   0.131625
# max     0.159333   0.158000   0.156667   0.160000   0.158000   0.160000
#
#             2021       2022
# count  42.000000  42.000000
# mean    0.129904   0.126658
# std     0.013262   0.012364
# min     0.090000   0.088000
# 25%     0.122167   0.122000
# 50%     0.127000   0.125250
# 75%     0.135333   0.134250
# max     0.164000   0.150667
#
# [8 rows x 23 columns]

# %%
# Which states have the lowest and highest O3 concentration?
low_O3 = O3_avg['2022'].min()
best_state_O3 = O3_avg.loc[O3_avg['2022'].idxmin(), 'State']
print(f'{best_state_O3} is the state with the lowest concentration of O3 with a value of {low_O3}')

high_O3 = O3_avg['2022'].max()
worst_state_O3 = O3_avg.loc[O3_avg['2022'].idxmax(), 'State']
print(f'{worst_state_O3} is the state with the highest concentration of O3 with a value of {high_O3}')
# Out:
# HI is the state with the lowest concentration of O3 with a value of 0.088
# CT is the state with the highest concentration of O3 with a value of 0.15066666666666664

# %%
#Summary statistics of PM25 concentration for each year by city.
city_pm25.describe()
# Out:
#              2000        2001        2002        2003        2004        2005  \
# count  169.000000  169.000000  169.000000  169.000000  169.000000  169.000000
# mean    26.081657   25.351479   24.798817   23.718343   22.933728   24.725444
# std      7.214549    6.745211    6.795079    5.986907    5.746706    6.629938
# min      8.400000    8.400000    8.000000    7.400000    6.800000    7.600000
# 25%     21.800000   21.400000   20.600000   19.400000   19.400000   20.600000
# 50%     26.200000   25.400000   25.400000   24.000000   23.200000   25.600000
# 75%     31.200000   29.600000   29.000000   28.000000   27.000000   29.200000
# max     47.800000   45.000000   46.400000   36.400000   36.200000   37.800000
#
#              2006        2007        2008        2009  ...        2013  \
# count  169.000000  169.000000  169.000000  169.000000  ...  169.000000
# mean    22.808284   23.159763   21.302959   19.377515  ...   17.679290
# std      5.612119    6.281325    5.299376    4.709789  ...    4.721441
# min      7.000000    8.000000    8.800000    7.600000  ...    9.400000
# 25%     18.600000   19.200000   18.200000   16.600000  ...   15.000000
# 50%     23.400000   24.000000   21.400000   19.400000  ...   17.400000
# 75%     27.000000   28.000000   24.400000   22.200000  ...   19.400000
# max     38.000000   43.800000   45.400000   41.400000  ...   42.800000
#
#              2014        2015        2016        2017        2018        2019  \
# count  169.000000  169.000000  169.000000  169.000000  169.000000  169.000000
# mean    17.461538   16.779882   15.353846   16.037870   16.504142   15.171598
# std      4.361684    3.944354    3.601587    3.972163    5.038853    3.133558
# min      7.800000    9.200000    5.800000    7.400000    6.400000    6.000000
# 25%     15.000000   14.600000   13.600000   14.200000   14.200000   13.600000
# 50%     17.800000   16.800000   15.200000   15.600000   15.800000   15.200000
# 75%     19.600000   18.600000   17.200000   17.200000   17.600000   17.000000
# max     40.200000   34.200000   30.600000   34.200000   37.200000   25.800000
#
#              2020        2021        2022
# count  169.000000  169.000000  169.000000
# mean    16.414201   17.138462   15.796450
# std      5.547740    4.644095    4.131498
# min      5.800000    5.000000    5.000000
# 25%     14.000000   14.800000   13.800000
# 50%     15.600000   16.600000   15.400000
# 75%     16.800000   18.800000   17.000000
# max     40.000000   41.400000   41.400000
#
# [8 rows x 23 columns]

# %%
# Which states have the lowest and highest PM2.5 concentration?
low_PM25 = city_pm25['2022'].min()
best_state_PM25 = city_pm25.loc[city_pm25['2022'].idxmin(), 'State']
print(f'{best_state_PM25} is the state with the lowest concentration of PM2.5 with an average value of {low_PM25}')

high_PM25 = city_pm25['2022'].max()
worst_state_PM25 = city_pm25.loc[city_pm25['2022'].idxmax(), 'State']
print(f'{worst_state_PM25} is the state with the highest concentration of PM2.5 with an average value of {high_PM25}')
# Out:
# HI is the state with the lowest concentration of PM2.5 with an average value of 5.0
# CA is the state with the highest concentration of PM2.5 with an average value of 41.4
